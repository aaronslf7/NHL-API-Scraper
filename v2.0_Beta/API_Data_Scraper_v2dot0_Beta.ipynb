# %% [markdown]
# # NHL API Scraper v1.1 (Beta)
#
# A hockey scraper for the new NHL API. The `game_id` parameter is the same used to call the NHL API. This script tries to improve on the speed and efficiency of the v1.0 which was largely smashed together just to get something to work. The `hockey_scraper` library now works again and is currently faster than this scraper but may as well use this scraper as I can get the exact data that I want from it.
#
# ### Implemented Functions
#
# - `get_away_roster(game_id)`: returns a dictionary with player names and IDs of the away roster.
# - `get_home_roster(game_id)`: returns a dictionary with player names and IDs of the home roster.
# - `get_game_roster(game_id)`: returns a dictionary with player names and IDs of both teams.
#
# - `get_away_positions(game_id)`: returns a dictionary with player IDs and player positions of the away roster.
# - `get_home_positions(game_id)`: returns a dictionary with player IDs and player positions of the home roster.
# - `get_game_positions(game_id)`: returns a dictionary with player IDs and player positions of both teams.
#
# - `get_play_by_play(game_id)`: returns a pandas DataFrame of the play-by-play.
# - `get_multi_play_by_play([list of game ids])`: returns a pandas DataFrame of the play-by-play of all the listed games.
#
#
# ### Other Functions to Implement
#
# - ?
#
# <br>
#
# ### Methods of Improvement
#
# - Faster for loop methods (use 'for item in list' rather than 'for i in range(len(list))'
# - Cutting out unnecessary loop run throughs
# - Differentiation of strength state into how many skaters on ice
#
# ## Current State
#
# - Need to correct get_play_by_play() function: ensure shifts are recorded correctly.
#
# ### Useful Endpoints
#
# - https://api-web.nhle.com/v1/gamecenter/2023020001/play-by-play
# - https://api-web.nhle.com/v1/player/8477474/landing
# - https://api-web.nhle.com/v1/gamecenter/2023020001/boxscore
#
# <br>

# %%
import requests
import pandas as pd
import numpy as np
from datetime import datetime

# %%
game_id = 2023020001

# %%
url = 'https://api-web.nhle.com/v1/gamecenter/{}/play-by-play'.format(game_id)
pbp = requests.get(url)
pbp_data = pbp.json()

# %%
pbp = pbp_data.get('plays')

# %%
types = [pbp[i].get('typeDescKey').upper() for i in range(len(pbp))]

# %%
set(types)
# Out:
# {'BLOCKED-SHOT',
#  'DELAYED-PENALTY',
#  'FACEOFF',
#  'GAME-END',
#  'GIVEAWAY',
#  'GOAL',
#  'HIT',
#  'MISSED-SHOT',
#  'PENALTY',
#  'PERIOD-END',
#  'PERIOD-START',
#  'SHOT-ON-GOAL',
#  'STOPPAGE',
#  'TAKEAWAY'}

# %%
url = 'https://api-web.nhle.com/v1/gamecenter/{}/boxscore'.format(2023020200)
pbp = requests.get(url)
pbp_data = pbp.json()

# %%
pbp_data
# Out:
# {'id': 2023020200,
#  'season': 20232024,
#  'gameType': 2,
#  'limitedScoring': False,
#  'gameDate': '2023-11-09',
#  'venue': {'default': 'Canada Life Centre'},
#  'venueLocation': {'default': 'Winnipeg'},
#  'startTimeUTC': '2023-11-10T01:00:00Z',
#  'easternUTCOffset': '-05:00',
#  'venueUTCOffset': '-06:00',
#  'tvBroadcasts': [{'id': 375,
#    'market': 'A',
#    'countryCode': 'US',
#    'network': 'BSSO',
#    'sequenceNumber': 70},
#   {'id': 292,
#    'market': 'H',
#    'countryCode': 'CA',
#    'network': 'TSN3',
#    'sequenceNumber': 75}],
#  'gameState': 'OFF',
#  'gameScheduleState': 'OK',
#  'periodDescriptor': {'number': 3, 'periodType': 'REG'},
#  'regPeriods': 3,
#  'awayTeam': {'id': 18,
#   'name': {'default': 'Predators'},
#   'abbrev': 'NSH',
#   'score': 3,
#   'sog': 23,
#   'logo': 'https://assets.nhle.com/logos/nhl/svg/NSH_light.svg',
#   'placeName': {'default': 'Nashville'}},
#  'homeTeam': {'id': 52,
#   'name': {'default': 'Jets'},
#   'abbrev': 'WPG',
#   'score': 6,
#   'sog': 37,
#   'logo': 'https://assets.nhle.com/logos/nhl/svg/WPG_light.svg',
#   'placeName': {'default': 'Winnipeg'}},
#  'clock': {'timeRemaining': '00:00',
#   'secondsRemaining': 0,
#   'running': False,
#   'inIntermission': False},
#  'playerByGameStats': {'awayTeam': {'forwards': [{'playerId': 8476887,
#      'sweaterNumber': 9,
#      'name': {'default': 'F. Forsberg'},
#      'position': 'L',
#      'goals': 2,
#      'assists': 0,
#      'points': 2,
#      'plusMinus': -2,
#      'pim': 0,
#      'hits': 0,
#      'powerPlayGoals': 0,
#      'shots': 3,
#      'faceoffWinningPctg': 0.0,
#      'toi': '20:51'},
#     {'playerId': 8476925,
#      'sweaterNumber': 10,
#      'name': {'default': 'C. Sissons'},
#      'position': 'C',
#      'goals': 0,
#      'assists': 0,
#      'points': 0,
#      'plusMinus': -1,
#      'pim': 0,
#      'hits': 2,
#      'powerPlayGoals': 0,
#      'shots': 0,
#      'faceoffWinningPctg': 0.7,
#      'toi': '16:45'},
#     {'playerId': 8478508,
#      'sweaterNumber': 13,
#      'name': {'default': 'Y. Trenin'},
#      'position': 'C',
#      'goals': 0,
#      'assists': 0,
#      'points': 0,
#      'plusMinus': -1,
#      'pim': 0,
#      'hits': 2,
#      'powerPlayGoals': 0,
#      'shots': 0,
#      'faceoffWinningPctg': 0.0,
#      'toi': '13:41'},
#     {'playerId': 8474679,
#      'sweaterNumber': 14,
#      'name': {'default': 'G. Nyquist'},
#      'position': 'C',
#      'goals': 0,
#      'assists': 1,
#      'points': 1,
#      'plusMinus': -2,
#      'pim': 2,
#      'hits': 0,
#      'powerPlayGoals': 0,
#      'shots': 1,
#      'faceoffWinningPctg': 0.0,
#      'toi': '14:35'},
#     {'playerId': 8480853,
#      'sweaterNumber': 18,
#      'name': {'default': 'L. Foudy'},
#      'position': 'C',
#      'goals': 0,
#      'assists': 0,
#      'points': 0,
#      'plusMinus': 0,
#      'pim': 0,
#      'hits': 0,
#      'powerPlayGoals': 0,
#      'shots': 1,
#      'faceoffWinningPctg': 0.0,
#      'toi': '09:56'},
#     {'playerId': 8481577,
#      'sweaterNumber': 26,
#      'name': {'default': 'P. Tomasino'},
#      'position': 'C',
#      'goals': 1,
#      'assists': 0,
#      'points': 1,
#      'plusMinus': 0,
#      'pim': 0,
#      'hits': 0,
#      'powerPlayGoals': 0,
#      'shots': 1,
#      'faceoffWinningPctg': 0.5,
#      'toi': '12:05'},
#     {'playerId': 8482062,
#      'sweaterNumber': 36,
#      'name': {'default': 'C. Smith'},
#      'position': 'L',
#      'goals': 0,
#      'assists': 0,
#      'points': 0,
#      'plusMinus': 0,
#      'pim': 17,
#      'hits': 3,
#      'powerPlayGoals': 0,
#      'shots': 0,
#      'faceoffWinningPctg': 0.0,
#      'toi': '07:32'},
#     {'playerId': 8480748,
#      'sweaterNumber': 44,
#      'name': {'default': 'K. Sherwood'},
#      'position': 'L',
#      'goals': 0,
#      'assists': 0,
#      'points': 0,
#      'plusMinus': 0,
#      'pim': 0,
#      'hits': 5,
#      'powerPlayGoals': 0,
#      'shots': 3,
#      'faceoffWinningPctg': 0.0,
#      'toi': '13:30'},
#     {'playerId': 8477446,
#      'sweaterNumber': 47,
#      'name': {'default': 'M. McCarron'},
#      'position': 'R',
#      'goals': 0,
#      'assists': 0,
#      'points': 0,
#      'plusMinus': 1,
#      'pim': 0,
#      'hits': 1,
#      'powerPlayGoals': 0,
#      'shots': 2,
#      'faceoffWinningPctg': 0.5,
#      'toi': '11:40'},
#     {'playerId': 8482146,
#      'sweaterNumber': 77,
#      'name': {'default': 'L. Evangelista'},
#      'position': 'R',
#      'goals': 0,
#      'assists': 0,
#      'points': 0,
#      'plusMinus': 0,
#      'pim': 0,
#      'hits': 0,
#      'powerPlayGoals': 0,
#      'shots': 2,
#      'faceoffWinningPctg': 0.0,
#      'toi': '19:51'},
#     {'playerId': 8478438,
#      'sweaterNumber': 82,
#      'name': {'default': 'T. Novak'},
#      'position': 'C',
#      'goals': 0,
#      'assists': 0,
#      'points': 0,
#      'plusMinus': 0,
#      'pim': 0,
#      'hits': 0,
#      'powerPlayGoals': 0,
#      'shots': 1,
#      'faceoffWinningPctg': 0.5,
#      'toi': '19:37'},
#     {'playerId': 8475158,
#      'sweaterNumber': 90,
#      'name': {'default': "R. O'Reilly"},
#      'position': 'C',
#      'goals': 0,
#      'assists': 0,
#      'points': 0,
#      'plusMinus': -3,
#      'pim': 2,
#      'hits': 0,
#      'powerPlayGoals': 0,
#      'shots': 3,
#      'faceoffWinningPctg': 0.5,
#      'toi': '19:58'}],
#    'defense': [{'playerId': 8478468,
#      'sweaterNumber': 3,
#      'name': {'default': 'J. Lauzon'},
#      'position': 'D',
#      'goals': 0,
#      'assists': 0,
#      'points': 0,
#      'plusMinus': -1,
#      'pim': 5,
#      'hits': 1,
#      'powerPlayGoals': 0,
#      'shots': 0,
#      'faceoffWinningPctg': 0.0,
#      'toi': '13:06'},
#     {'playerId': 8481743,
#      'sweaterNumber': 7,
#      'name': {'default': 'M. Del Gaizo'},
#      'position': 'D',
#      'goals': 0,
#      'assists': 1,
#      'points': 1,
#      'plusMinus': 0,
#      'pim': 2,
#      'hits': 0,
#      'powerPlayGoals': 0,
#      'shots': 2,
#      'faceoffWinningPctg': 0.0,
#      'toi': '18:07'},
#     {'playerId': 8475197,
#      'sweaterNumber': 22,
#      'name': {'default': 'T. Barrie'},
#      'position': 'D',
#      'goals': 0,
#      'assists': 2,
#      'points': 2,
#      'plusMinus': -1,
#      'pim': 0,
#      'hits': 0,
#      'powerPlayGoals': 0,
#      'shots': 1,
#      'faceoffWinningPctg': 0.0,
#      'toi': '17:45'},
#     {'playerId': 8478851,
#      'sweaterNumber': 45,
#      'name': {'default': 'A. Carrier'},
#      'position': 'D',
#      'goals': 0,
#      'assists': 0,
#      'points': 0,
#      'plusMinus': -1,
#      'pim': 0,
#      'hits': 1,
#      'powerPlayGoals': 0,
#      'shots': 1,
#      'faceoffWinningPctg': 0.0,
#      'toi': '17:39'},
#     {'playerId': 8479371,
#      'sweaterNumber': 57,
#      'name': {'default': 'D. Fabbro'},
#      'position': 'D',
#      'goals': 0,
#      'assists': 0,
#      'points': 0,
#      'plusMinus': 0,
#      'pim': 0,
#      'hits': 0,
#      'powerPlayGoals': 0,
#      'shots': 1,
#      'faceoffWinningPctg': 0.0,
#      'toi': '18:51'},
#     {'playerId': 8474600,
#      'sweaterNumber': 59,
#      'name': {'default': 'R. Josi'},
#      'position': 'D',
#      'goals': 0,
#      'assists': 0,
#      'points': 0,
#      'plusMinus': -1,
#      'pim': 0,
#      'hits': 0,
#      'powerPlayGoals': 0,
#      'shots': 1,
#      'faceoffWinningPctg': 0.0,
#      'toi': '28:47'}],
#    'goalies': [{'playerId': 8480947,
#      'sweaterNumber': 32,
#      'name': {'default': 'K. Lankinen'},
#      'position': 'G',
#      'evenStrengthShotsAgainst': '0/0',
#      'powerPlayShotsAgainst': '0/0',
#      'shorthandedShotsAgainst': '0/0',
#      'saveShotsAgainst': '0/0',
#      'evenStrengthGoalsAgainst': 0,
#      'powerPlayGoalsAgainst': 0,
#      'shorthandedGoalsAgainst': 0,
#      'pim': 0,
#      'goalsAgainst': 0,
#      'toi': '00:00',
#      'starter': False},
#     {'playerId': 8477424,
#      'sweaterNumber': 74,
#      'name': {'default': 'J. Saros'},
#      'position': 'G',
#      'evenStrengthShotsAgainst': '21/25',
#      'powerPlayShotsAgainst': '7/8',
#      'shorthandedShotsAgainst': '3/3',
#      'saveShotsAgainst': '31/36',
#      'savePctg': '0.861',
#      'evenStrengthGoalsAgainst': 4,
#      'powerPlayGoalsAgainst': 1,
#      'shorthandedGoalsAgainst': 0,
#      'pim': 0,
#      'goalsAgainst': 5,
#      'toi': '57:46',
#      'starter': True,
#      'decision': 'L'}]},
#   'homeTeam': {'forwards': [{'playerId': 8476480,
#      'sweaterNumber': 7,
#      'name': {'default': 'V. Namestnikov', 'cs': 'V. Naměstnikov'},
#      'position': 'C',
#      'goals': 0,
#      'assists': 0,
#      'points': 0,
#      'plusMinus': 0,
#      'pim': 0,
#      'hits': 1,
#      'powerPlayGoals': 0,
#      'shots': 2,
#      'faceoffWinningPctg': 0.444444,
#      'toi': '17:40'},
#     {'playerId': 8480113,
#      'sweaterNumber': 9,
#      'name': {'default': 'A. Iafallo'},
#      'position': 'L',
#      'goals': 0,
#      'assists': 2,
#      'points': 2,
#      'plusMinus': 2,
#      'pim': 0,
#      'hits': 2,
#      'powerPlayGoals': 0,
#      'shots': 4,
#      'faceoffWinningPctg': 0.0,
#      'toi': '16:26'},
#     {'playerId': 8480845,
#      'sweaterNumber': 15,
#      'name': {'default': 'R. Kupari'},
#      'position': 'C',
#      'goals': 0,
#      'assists': 0,
#      'points': 0,
#      'plusMinus': 0,
#      'pim': 0,
#      'hits': 0,
#      'powerPlayGoals': 0,
#      'shots': 2,
#      'faceoffWinningPctg': 0.428571,
#      'toi': '08:34'},
#     {'playerId': 8476392,
#      'sweaterNumber': 17,
#      'name': {'default': 'A. Lowry'},
#      'position': 'C',
#      'goals': 0,
#      'assists': 1,
#      'points': 1,
#      'plusMinus': 0,
#      'pim': 10,
#      'hits': 3,
#      'powerPlayGoals': 0,
#      'shots': 0,
#      'faceoffWinningPctg': 0.384615,
#      'toi': '13:26'},
#     {'playerId': 8481019,
#      'sweaterNumber': 19,
#      'name': {'default': 'D. Gustafsson'},
#      'position': 'C',
#      'goals': 0,
#      'assists': 0,
#      'points': 0,
#      'plusMinus': 0,
#      'pim': 0,
#      'hits': 0,
#      'powerPlayGoals': 0,
#      'shots': 0,
#      'faceoffWinningPctg': 0.6,
#      'toi': '07:41'},
#     {'playerId': 8478891,
#      'sweaterNumber': 22,
#      'name': {'default': 'M. Appleton'},
#      'position': 'C',
#      'goals': 1,
#      'assists': 0,
#      'points': 1,
#      'plusMinus': 0,
#      'pim': 0,
#      'hits': 1,
#      'powerPlayGoals': 0,
#      'shots': 2,
#      'faceoffWinningPctg': 1.0,
#      'toi': '19:03'},
#     {'playerId': 8477940,
#      'sweaterNumber': 27,
#      'name': {'default': 'N. Ehlers'},
#      'position': 'L',
#      'goals': 0,
#      'assists': 0,
#      'points': 0,
#      'plusMinus': 0,
#      'pim': 2,
#      'hits': 0,
#      'powerPlayGoals': 0,
#      'shots': 4,
#      'faceoffWinningPctg': 0.0,
#      'toi': '13:25'},
#     {'playerId': 8480289,
#      'sweaterNumber': 36,
#      'name': {'default': 'M. Barron'},
#      'position': 'C',
#      'goals': 0,
#      'assists': 1,
#      'points': 1,
#      'plusMinus': 1,
#      'pim': 0,
#      'hits': 0,
#      'powerPlayGoals': 0,
#      'shots': 4,
#      'faceoffWinningPctg': 0.0,
#      'toi': '10:09'},
#     {'playerId': 8476460,
#      'sweaterNumber': 55,
#      'name': {'default': 'M. Scheifele'},
#      'position': 'C',
#      'goals': 0,
#      'assists': 4,
#      'points': 4,
#      'plusMinus': 2,
#      'pim': 0,
#      'hits': 1,
#      'powerPlayGoals': 0,
#      'shots': 4,
#      'faceoffWinningPctg': 0.555556,
#      'toi': '18:12'},
#     {'playerId': 8475799,
#      'sweaterNumber': 62,
#      'name': {'default': 'N. Niederreiter'},
#      'position': 'R',
#      'goals': 0,
#      'assists': 1,
#      'points': 1,
#      'plusMinus': 0,
#      'pim': 0,
#      'hits': 1,
#      'powerPlayGoals': 0,
#      'shots': 1,
#      'faceoffWinningPctg': 1.0,
#      'toi': '14:57'},
#     {'playerId': 8478398,
#      'sweaterNumber': 81,
#      'name': {'default': 'K. Connor'},
#      'position': 'L',
#      'goals': 3,
#      'assists': 1,
#      'points': 4,
#      'plusMinus': 2,
#      'pim': 0,
#      'hits': 0,
#      'powerPlayGoals': 0,
#      'shots': 7,
#      'faceoffWinningPctg': 0.0,
#      'toi': '18:28'},
#     {'playerId': 8482149,
#      'sweaterNumber': 91,
#      'name': {'default': 'C. Perfetti'},
#      'position': 'C',
#      'goals': 1,
#      'assists': 0,
#      'points': 1,
#      'plusMinus': 0,
#      'pim': 2,
#      'hits': 0,
#      'powerPlayGoals': 1,
#      'shots': 2,
#      'faceoffWinningPctg': 0.0,
#      'toi': '14:50'}],
#    'defense': [{'playerId': 8476331,
#      'sweaterNumber': 2,
#      'name': {'default': 'D. DeMelo',
#       'cs': 'D. Demelo',
#       'de': 'D. Demelo',
#       'fi': 'D. Demelo',
#       'sk': 'D. Demelo',
#       'sv': 'D. Demelo'},
#      'position': 'D',
#      'goals': 0,
#      'assists': 2,
#      'points': 2,
#      'plusMinus': 2,
#      'pim': 0,
#      'hits': 0,
#      'powerPlayGoals': 0,
#      'shots': 1,
#      'faceoffWinningPctg': 0.0,
#      'toi': '20:27'},
#     {'playerId': 8480145,
#      'sweaterNumber': 4,
#      'name': {'default': 'N. Pionk',
#       'cs': 'N.Pionk',
#       'de': 'N.Pionk',
#       'fi': 'N.Pionk',
#       'sk': 'N.Pionk',
#       'sv': 'N.Pionk'},
#      'position': 'D',
#      'goals': 0,
#      'assists': 0,
#      'points': 0,
#      'plusMinus': 1,
#      'pim': 0,
#      'hits': 4,
#      'powerPlayGoals': 0,
#      'shots': 2,
#      'faceoffWinningPctg': 0.0,
#      'toi': '20:08'},
#     {'playerId': 8475455,
#      'sweaterNumber': 5,
#      'name': {'default': 'B. Dillon'},
#      'position': 'D',
#      'goals': 1,
#      'assists': 0,
#      'points': 1,
#      'plusMinus': 1,
#      'pim': 2,
#      'hits': 5,
#      'powerPlayGoals': 0,
#      'shots': 1,
#      'faceoffWinningPctg': 0.0,
#      'toi': '18:29'},
#     {'playerId': 8477504,
#      'sweaterNumber': 44,
#      'name': {'default': 'J. Morrissey'},
#      'position': 'D',
#      'goals': 0,
#      'assists': 0,
#      'points': 0,
#      'plusMinus': 1,
#      'pim': 0,
#      'hits': 0,
#      'powerPlayGoals': 0,
#      'shots': 1,
#      'faceoffWinningPctg': 0.0,
#      'toi': '21:51'},
#     {'playerId': 8480049,
#      'sweaterNumber': 54,
#      'name': {'default': 'D. Samberg'},
#      'position': 'D',
#      'goals': 0,
#      'assists': 0,
#      'points': 0,
#      'plusMinus': 0,
#      'pim': 0,
#      'hits': 0,
#      'powerPlayGoals': 0,
#      'shots': 0,
#      'faceoffWinningPctg': 0.0,
#      'toi': '17:53'},
#     {'playerId': 8477220,
#      'sweaterNumber': 88,
#      'name': {'default': 'N. Schmidt'},
#      'position': 'D',
#      'goals': 0,
#      'assists': 0,
#      'points': 0,
#      'plusMinus': -1,
#      'pim': 0,
#      'hits': 2,
#      'powerPlayGoals': 0,
#      'shots': 0,
#      'faceoffWinningPctg': 0.0,
#      'toi': '18:27'}],
#    'goalies': [{'playerId': 8476945,
#      'sweaterNumber': 37,
#      'name': {'default': 'C. Hellebuyck'},
#      'position': 'G',
#      'evenStrengthShotsAgainst': '0/0',
#      'powerPlayShotsAgainst': '0/0',
#      'shorthandedShotsAgainst': '0/0',
#      'saveShotsAgainst': '0/0',
#      'evenStrengthGoalsAgainst': 0,
#      'powerPlayGoalsAgainst': 0,
#      'shorthandedGoalsAgainst': 0,
#      'pim': 0,
#      'goalsAgainst': 0,
#      'toi': '00:00',
#      'starter': False},
#     {'playerId': 8476316,
#      'sweaterNumber': 39,
#      'name': {'default': 'L. Brossoit'},
#      'position': 'G',
#      'evenStrengthShotsAgainst': '14/17',
#      'powerPlayShotsAgainst': '5/5',
#      'shorthandedShotsAgainst': '1/1',
#      'saveShotsAgainst': '20/23',
#      'savePctg': '0.870',
#      'evenStrengthGoalsAgainst': 3,
#      'powerPlayGoalsAgainst': 0,
#      'shorthandedGoalsAgainst': 0,
#      'pim': 0,
#      'goalsAgainst': 3,
#      'toi': '60:00',
#      'starter': True,
#      'decision': 'W'}]}},
#  'summary': {'linescore': {'byPeriod': [{'periodDescriptor': {'number': 1,
#       'periodType': 'REG'},
#      'away': 1,
#      'home': 1},
#     {'periodDescriptor': {'number': 2, 'periodType': 'REG'},
#      'away': 1,
#      'home': 3},
#     {'periodDescriptor': {'number': 3, 'periodType': 'REG'},
#      'away': 1,
#      'home': 2}],
#    'totals': {'away': 3, 'home': 6}},
#   'shotsByPeriod': [{'periodDescriptor': {'number': 1, 'periodType': 'REG'},
#     'away': 7,
#     'home': 14},
#    {'periodDescriptor': {'number': 2, 'periodType': 'REG'},
#     'away': 8,
#     'home': 14},
#    {'periodDescriptor': {'number': 3, 'periodType': 'REG'},
#     'away': 8,
#     'home': 9}],
#   'teamGameStats': [{'category': 'sog', 'awayValue': 23, 'homeValue': 37},
#    {'category': 'faceoffWinningPctg',
#     'awayValue': 0.517857,
#     'homeValue': 0.482143},
#    {'category': 'powerPlay', 'awayValue': '0/5', 'homeValue': '1/4'},
#    {'category': 'powerPlayPctg', 'awayValue': 0.0, 'homeValue': 0.25},
#    {'category': 'pim', 'awayValue': 28, 'homeValue': 20},
#    {'category': 'hits', 'awayValue': 15, 'homeValue': 20},
#    {'category': 'blockedShots', 'awayValue': 14, 'homeValue': 15},
#    {'category': 'giveaways', 'awayValue': 6, 'homeValue': 4},
#    {'category': 'takeaways', 'awayValue': 2, 'homeValue': 2}],
#   'seasonSeries': [{'id': 2023020200,
#     'season': 20232024,
#     'gameType': 2,
#     'gameDate': '2023-11-09',
#     'startTimeUTC': '2023-11-10T01:00:00Z',
#     'easternUTCOffset': '-05:00',
#     'venueUTCOffset': '-06:00',
#     'gameState': 'OFF',
#     'gameScheduleState': 'OK',
#     'awayTeam': {'id': 18,
#      'abbrev': 'NSH',
#      'logo': 'https://assets.nhle.com/logos/nhl/svg/NSH_light.svg',
#      'score': 3},
#     'homeTeam': {'id': 52,
#      'abbrev': 'WPG',
#      'logo': 'https://assets.nhle.com/logos/nhl/svg/WPG_light.svg',
#      'score': 6},
#     'clock': {'timeRemaining': '00:00',
#      'secondsRemaining': 0,
#      'running': False,
#      'inIntermission': False},
#     'gameCenterLink': '/gamecenter/nsh-vs-wpg/2023/11/09/2023020200',
#     'periodDescriptor': {'number': 3, 'periodType': 'REG'},
#     'gameOutcome': {'lastPeriodType': 'REG'}},
#    {'id': 2023020319,
#     'season': 20232024,
#     'gameType': 2,
#     'gameDate': '2023-11-26',
#     'startTimeUTC': '2023-11-27T01:00:00Z',
#     'easternUTCOffset': '-05:00',
#     'venueUTCOffset': '-06:00',
#     'gameState': 'OFF',
#     'gameScheduleState': 'OK',
#     'awayTeam': {'id': 52,
#      'abbrev': 'WPG',
#      'logo': 'https://assets.nhle.com/logos/nhl/svg/WPG_light.svg',
#      'score': 2},
#     'homeTeam': {'id': 18,
#      'abbrev': 'NSH',
#      'logo': 'https://assets.nhle.com/logos/nhl/svg/NSH_light.svg',
#      'score': 3},
#     'clock': {'timeRemaining': '00:00',
#      'secondsRemaining': 0,
#      'running': False,
#      'inIntermission': False},
#     'gameCenterLink': '/gamecenter/wpg-vs-nsh/2023/11/26/2023020319',
#     'periodDescriptor': {'number': 3, 'periodType': 'REG'},
#     'gameOutcome': {'lastPeriodType': 'REG'}},
#    {'id': 2023021042,
#     'season': 20232024,
#     'gameType': 2,
#     'gameDate': '2024-03-13',
#     'startTimeUTC': '2024-03-13T23:30:00Z',
#     'easternUTCOffset': '-04:00',
#     'venueUTCOffset': '-05:00',
#     'gameState': 'OFF',
#     'gameScheduleState': 'OK',
#     'awayTeam': {'id': 18,
#      'abbrev': 'NSH',
#      'logo': 'https://assets.nhle.com/logos/nhl/svg/NSH_light.svg',
#      'score': 4},
#     'homeTeam': {'id': 52,
#      'abbrev': 'WPG',
#      'logo': 'https://assets.nhle.com/logos/nhl/svg/WPG_light.svg',
#      'score': 2},
#     'clock': {'timeRemaining': '00:00',
#      'secondsRemaining': 0,
#      'running': False,
#      'inIntermission': False},
#     'gameCenterLink': '/gamecenter/nsh-vs-wpg/2024/03/13/2023021042',
#     'periodDescriptor': {'number': 3, 'periodType': 'REG'},
#     'gameOutcome': {'lastPeriodType': 'REG'}},
#    {'id': 2023021247,
#     'season': 20232024,
#     'gameType': 2,
#     'gameDate': '2024-04-09',
#     'startTimeUTC': '2024-04-10T00:00:00Z',
#     'easternUTCOffset': '-04:00',
#     'venueUTCOffset': '-05:00',
#     'gameState': 'OFF',
#     'gameScheduleState': 'OK',
#     'awayTeam': {'id': 52,
#      'abbrev': 'WPG',
#      'logo': 'https://assets.nhle.com/logos/nhl/svg/WPG_light.svg',
#      'score': 4},
#     'homeTeam': {'id': 18,
#      'abbrev': 'NSH',
#      'logo': 'https://assets.nhle.com/logos/nhl/svg/NSH_light.svg',
#      'score': 3},
#     'clock': {'timeRemaining': '03:08',
#      'secondsRemaining': 188,
#      'running': False,
#      'inIntermission': False},
#     'gameCenterLink': '/gamecenter/wpg-vs-nsh/2024/04/09/2023021247',
#     'periodDescriptor': {'number': 4, 'periodType': 'OT'},
#     'gameOutcome': {'lastPeriodType': 'OT', 'otPeriods': 1}}],
#   'seasonSeriesWins': {'awayTeamWins': 2, 'homeTeamWins': 2},
#   'gameReports': {'gameSummary': 'https://www.nhl.com/scores/htmlreports/20232024/GS020200.HTM',
#    'eventSummary': 'https://www.nhl.com/scores/htmlreports/20232024/ES020200.HTM',
#    'playByPlay': 'https://www.nhl.com/scores/htmlreports/20232024/PL020200.HTM',
#    'faceoffSummary': 'https://www.nhl.com/scores/htmlreports/20232024/FS020200.HTM',
#    'faceoffComparison': 'https://www.nhl.com/scores/htmlreports/20232024/FC020200.HTM',
#    'rosters': 'https://www.nhl.com/scores/htmlreports/20232024/RO020200.HTM',
#    'shotSummary': 'https://www.nhl.com/scores/htmlreports/20232024/SS020200.HTM',
#    'shiftChart': 'https://www.nhl.com/stats/shiftcharts?id=2023020200',
#    'toiAway': 'https://www.nhl.com/scores/htmlreports/20232024/TV020200.HTM',
#    'toiHome': 'https://www.nhl.com/scores/htmlreports/20232024/TH020200.HTM'},
#   'gameInfo': {'referees': [{'default': 'Carter Sandlak'},
#     {'default': 'Kendrick Nicholson'}],
#    'linesmen': [{'default': 'Justin Johnson'}, {'default': 'Devin Berg'}],
#    'awayTeam': {'headCoach': {'default': 'Andrew Brunette'},
#     'scratches': [{'id': 8474151,
#       'firstName': {'default': 'Ryan'},
#       'lastName': {'default': 'McDonagh'}},
#      {'id': 8481239,
#       'firstName': {'default': 'Samuel'},
#       'lastName': {'default': 'Fagemo'}},
#      {'id': 8481704,
#       'firstName': {'default': 'Juuso'},
#       'lastName': {'default': 'Parssinen'}}]},
#    'homeTeam': {'headCoach': {'default': 'Rick Bowness'},
#     'scratches': [{'id': 8479378,
#       'firstName': {'default': 'Logan'},
#       'lastName': {'default': 'Stanley'}},
#      {'id': 8480990,
#       'firstName': {'default': 'Declan'},
#       'lastName': {'default': 'Chisholm'}}]}}},
#  'gameOutcome': {'lastPeriodType': 'REG'},
#  'gameVideo': {'threeMinRecap': 6340842459112, 'condensedGame': 6340841282112}}

# %%
pbp_data.get('playerByGameStats').get('awayTeam')
# Out:
# {'forwards': [{'playerId': 8476887,
#    'sweaterNumber': 9,
#    'name': {'default': 'F. Forsberg'},
#    'position': 'L',
#    'goals': 2,
#    'assists': 0,
#    'points': 2,
#    'plusMinus': -2,
#    'pim': 0,
#    'hits': 0,
#    'powerPlayGoals': 0,
#    'shots': 3,
#    'faceoffWinningPctg': 0.0,
#    'toi': '20:51'},
#   {'playerId': 8476925,
#    'sweaterNumber': 10,
#    'name': {'default': 'C. Sissons'},
#    'position': 'C',
#    'goals': 0,
#    'assists': 0,
#    'points': 0,
#    'plusMinus': -1,
#    'pim': 0,
#    'hits': 2,
#    'powerPlayGoals': 0,
#    'shots': 0,
#    'faceoffWinningPctg': 0.7,
#    'toi': '16:45'},
#   {'playerId': 8478508,
#    'sweaterNumber': 13,
#    'name': {'default': 'Y. Trenin'},
#    'position': 'C',
#    'goals': 0,
#    'assists': 0,
#    'points': 0,
#    'plusMinus': -1,
#    'pim': 0,
#    'hits': 2,
#    'powerPlayGoals': 0,
#    'shots': 0,
#    'faceoffWinningPctg': 0.0,
#    'toi': '13:41'},
#   {'playerId': 8474679,
#    'sweaterNumber': 14,
#    'name': {'default': 'G. Nyquist'},
#    'position': 'C',
#    'goals': 0,
#    'assists': 1,
#    'points': 1,
#    'plusMinus': -2,
#    'pim': 2,
#    'hits': 0,
#    'powerPlayGoals': 0,
#    'shots': 1,
#    'faceoffWinningPctg': 0.0,
#    'toi': '14:35'},
#   {'playerId': 8480853,
#    'sweaterNumber': 18,
#    'name': {'default': 'L. Foudy'},
#    'position': 'C',
#    'goals': 0,
#    'assists': 0,
#    'points': 0,
#    'plusMinus': 0,
#    'pim': 0,
#    'hits': 0,
#    'powerPlayGoals': 0,
#    'shots': 1,
#    'faceoffWinningPctg': 0.0,
#    'toi': '09:56'},
#   {'playerId': 8481577,
#    'sweaterNumber': 26,
#    'name': {'default': 'P. Tomasino'},
#    'position': 'C',
#    'goals': 1,
#    'assists': 0,
#    'points': 1,
#    'plusMinus': 0,
#    'pim': 0,
#    'hits': 0,
#    'powerPlayGoals': 0,
#    'shots': 1,
#    'faceoffWinningPctg': 0.5,
#    'toi': '12:05'},
#   {'playerId': 8482062,
#    'sweaterNumber': 36,
#    'name': {'default': 'C. Smith'},
#    'position': 'L',
#    'goals': 0,
#    'assists': 0,
#    'points': 0,
#    'plusMinus': 0,
#    'pim': 17,
#    'hits': 3,
#    'powerPlayGoals': 0,
#    'shots': 0,
#    'faceoffWinningPctg': 0.0,
#    'toi': '07:32'},
#   {'playerId': 8480748,
#    'sweaterNumber': 44,
#    'name': {'default': 'K. Sherwood'},
#    'position': 'L',
#    'goals': 0,
#    'assists': 0,
#    'points': 0,
#    'plusMinus': 0,
#    'pim': 0,
#    'hits': 5,
#    'powerPlayGoals': 0,
#    'shots': 3,
#    'faceoffWinningPctg': 0.0,
#    'toi': '13:30'},
#   {'playerId': 8477446,
#    'sweaterNumber': 47,
#    'name': {'default': 'M. McCarron'},
#    'position': 'R',
#    'goals': 0,
#    'assists': 0,
#    'points': 0,
#    'plusMinus': 1,
#    'pim': 0,
#    'hits': 1,
#    'powerPlayGoals': 0,
#    'shots': 2,
#    'faceoffWinningPctg': 0.5,
#    'toi': '11:40'},
#   {'playerId': 8482146,
#    'sweaterNumber': 77,
#    'name': {'default': 'L. Evangelista'},
#    'position': 'R',
#    'goals': 0,
#    'assists': 0,
#    'points': 0,
#    'plusMinus': 0,
#    'pim': 0,
#    'hits': 0,
#    'powerPlayGoals': 0,
#    'shots': 2,
#    'faceoffWinningPctg': 0.0,
#    'toi': '19:51'},
#   {'playerId': 8478438,
#    'sweaterNumber': 82,
#    'name': {'default': 'T. Novak'},
#    'position': 'C',
#    'goals': 0,
#    'assists': 0,
#    'points': 0,
#    'plusMinus': 0,
#    'pim': 0,
#    'hits': 0,
#    'powerPlayGoals': 0,
#    'shots': 1,
#    'faceoffWinningPctg': 0.5,
#    'toi': '19:37'},
#   {'playerId': 8475158,
#    'sweaterNumber': 90,
#    'name': {'default': "R. O'Reilly"},
#    'position': 'C',
#    'goals': 0,
#    'assists': 0,
#    'points': 0,
#    'plusMinus': -3,
#    'pim': 2,
#    'hits': 0,
#    'powerPlayGoals': 0,
#    'shots': 3,
#    'faceoffWinningPctg': 0.5,
#    'toi': '19:58'}],
#  'defense': [{'playerId': 8478468,
#    'sweaterNumber': 3,
#    'name': {'default': 'J. Lauzon'},
#    'position': 'D',
#    'goals': 0,
#    'assists': 0,
#    'points': 0,
#    'plusMinus': -1,
#    'pim': 5,
#    'hits': 1,
#    'powerPlayGoals': 0,
#    'shots': 0,
#    'faceoffWinningPctg': 0.0,
#    'toi': '13:06'},
#   {'playerId': 8481743,
#    'sweaterNumber': 7,
#    'name': {'default': 'M. Del Gaizo'},
#    'position': 'D',
#    'goals': 0,
#    'assists': 1,
#    'points': 1,
#    'plusMinus': 0,
#    'pim': 2,
#    'hits': 0,
#    'powerPlayGoals': 0,
#    'shots': 2,
#    'faceoffWinningPctg': 0.0,
#    'toi': '18:07'},
#   {'playerId': 8475197,
#    'sweaterNumber': 22,
#    'name': {'default': 'T. Barrie'},
#    'position': 'D',
#    'goals': 0,
#    'assists': 2,
#    'points': 2,
#    'plusMinus': -1,
#    'pim': 0,
#    'hits': 0,
#    'powerPlayGoals': 0,
#    'shots': 1,
#    'faceoffWinningPctg': 0.0,
#    'toi': '17:45'},
#   {'playerId': 8478851,
#    'sweaterNumber': 45,
#    'name': {'default': 'A. Carrier'},
#    'position': 'D',
#    'goals': 0,
#    'assists': 0,
#    'points': 0,
#    'plusMinus': -1,
#    'pim': 0,
#    'hits': 1,
#    'powerPlayGoals': 0,
#    'shots': 1,
#    'faceoffWinningPctg': 0.0,
#    'toi': '17:39'},
#   {'playerId': 8479371,
#    'sweaterNumber': 57,
#    'name': {'default': 'D. Fabbro'},
#    'position': 'D',
#    'goals': 0,
#    'assists': 0,
#    'points': 0,
#    'plusMinus': 0,
#    'pim': 0,
#    'hits': 0,
#    'powerPlayGoals': 0,
#    'shots': 1,
#    'faceoffWinningPctg': 0.0,
#    'toi': '18:51'},
#   {'playerId': 8474600,
#    'sweaterNumber': 59,
#    'name': {'default': 'R. Josi'},
#    'position': 'D',
#    'goals': 0,
#    'assists': 0,
#    'points': 0,
#    'plusMinus': -1,
#    'pim': 0,
#    'hits': 0,
#    'powerPlayGoals': 0,
#    'shots': 1,
#    'faceoffWinningPctg': 0.0,
#    'toi': '28:47'}],
#  'goalies': [{'playerId': 8480947,
#    'sweaterNumber': 32,
#    'name': {'default': 'K. Lankinen'},
#    'position': 'G',
#    'evenStrengthShotsAgainst': '0/0',
#    'powerPlayShotsAgainst': '0/0',
#    'shorthandedShotsAgainst': '0/0',
#    'saveShotsAgainst': '0/0',
#    'evenStrengthGoalsAgainst': 0,
#    'powerPlayGoalsAgainst': 0,
#    'shorthandedGoalsAgainst': 0,
#    'pim': 0,
#    'goalsAgainst': 0,
#    'toi': '00:00',
#    'starter': False},
#   {'playerId': 8477424,
#    'sweaterNumber': 74,
#    'name': {'default': 'J. Saros'},
#    'position': 'G',
#    'evenStrengthShotsAgainst': '21/25',
#    'powerPlayShotsAgainst': '7/8',
#    'shorthandedShotsAgainst': '3/3',
#    'saveShotsAgainst': '31/36',
#    'savePctg': '0.861',
#    'evenStrengthGoalsAgainst': 4,
#    'powerPlayGoalsAgainst': 1,
#    'shorthandedGoalsAgainst': 0,
#    'pim': 0,
#    'goalsAgainst': 5,
#    'toi': '57:46',
#    'starter': True,
#    'decision': 'L'}]}

# %%
url = 'https://api-web.nhle.com/v1/player/{}/landing'.format(8477474)
pbp = requests.get(url)
pbp_data = pbp.json()
pbp_data
# Out:
# {'playerId': 8477474,
#  'isActive': False,
#  'firstName': {'default': 'Madison'},
#  'lastName': {'default': 'Bowey'},
#  'sweaterNumber': 24,
#  'position': 'D',
#  'headshot': 'https://assets.nhle.com/mugs/nhl/latest/8477474.png',
#  'heroImage': 'https://assets.nhle.com/mugs/actionshots/1296x729/8477474.jpg',
#  'heightInInches': 73,
#  'heightInCentimeters': 185,
#  'weightInPounds': 207,
#  'weightInKilograms': 94,
#  'birthDate': '1995-04-22',
#  'birthCity': {'default': 'Winnipeg'},
#  'birthStateProvince': {'default': 'Manitoba'},
#  'birthCountry': 'CAN',
#  'shootsCatches': 'R',
#  'draftDetails': {'year': 2013,
#   'teamAbbrev': 'WSH',
#   'round': 2,
#   'pickInRound': 23,
#   'overallPick': 53},
#  'playerSlug': 'madison-bowey-8477474',
#  'inTop100AllTime': 0,
#  'inHHOF': 0,
#  'featuredStats': {'season': 20212022,
#   'regularSeason': {'subSeason': {'assists': 0,
#     'gameWinningGoals': 0,
#     'gamesPlayed': 2,
#     'goals': 0,
#     'otGoals': 0,
#     'pim': 0,
#     'plusMinus': -3,
#     'points': 0,
#     'powerPlayGoals': 0,
#     'powerPlayPoints': 0,
#     'shootingPctg': 0.0,
#     'shorthandedGoals': 0,
#     'shorthandedPoints': 0,
#     'shots': 0},
#    'career': {'assists': 35,
#     'gameWinningGoals': 1,
#     'gamesPlayed': 158,
#     'goals': 5,
#     'otGoals': 0,
#     'pim': 104,
#     'plusMinus': -22,
#     'points': 40,
#     'powerPlayGoals': 0,
#     'powerPlayPoints': 1,
#     'shootingPctg': 0.030299999999999997,
#     'shorthandedGoals': 0,
#     'shorthandedPoints': 0,
#     'shots': 165}}},
#  'careerTotals': {'regularSeason': {'assists': 35,
#    'avgToi': '15:36',
#    'gameWinningGoals': 1,
#    'gamesPlayed': 158,
#    'goals': 5,
#    'otGoals': 0,
#    'pim': 104,
#    'plusMinus': -22,
#    'points': 40,
#    'powerPlayGoals': 0,
#    'powerPlayPoints': 1,
#    'shootingPctg': 0.030299999999999997,
#    'shorthandedGoals': 0,
#    'shorthandedPoints': 0,
#    'shots': 165}},
#  'shopLink': '#TODO',
#  'twitterLink': '#TODO',
#  'watchLink': '#TODO',
#  'last5Games': [{'assists': 0,
#    'gameDate': '2021-11-14',
#    'gameId': 2021020229,
#    'gameTypeId': 2,
#    'goals': 0,
#    'homeRoadFlag': 'R',
#    'opponentAbbrev': 'ANA',
#    'pim': 0,
#    'plusMinus': -1,
#    'points': 0,
#    'powerPlayGoals': 0,
#    'shifts': 22,
#    'shorthandedGoals': 0,
#    'shots': 0,
#    'teamAbbrev': 'VAN',
#    'toi': '16:53'},
#   {'assists': 0,
#    'gameDate': '2021-11-13',
#    'gameId': 2021020222,
#    'gameTypeId': 2,
#    'goals': 0,
#    'homeRoadFlag': 'R',
#    'opponentAbbrev': 'VGK',
#    'pim': 0,
#    'plusMinus': -2,
#    'points': 0,
#    'powerPlayGoals': 0,
#    'shifts': 24,
#    'shorthandedGoals': 0,
#    'shots': 0,
#    'teamAbbrev': 'VAN',
#    'toi': '14:35'}],
#  'seasonTotals': [{'assists': 53,
#    'gameTypeId': 2,
#    'gamesPlayed': 29,
#    'goals': 16,
#    'leagueAbbrev': 'WBAAA',
#    'pim': 74,
#    'plusMinus': 0,
#    'points': 69,
#    'season': 20092010,
#    'sequence': 129109,
#    'teamName': {'default': 'Winnipeg Monarchs Bantam AAA'}},
#   {'assists': 22,
#    'gameTypeId': 2,
#    'gamesPlayed': 41,
#    'goals': 16,
#    'leagueAbbrev': 'MMHL',
#    'pim': 35,
#    'points': 38,
#    'season': 20102011,
#    'sequence': 1,
#    'teamName': {'default': 'Wpg. Wild'}},
#   {'assists': 1,
#    'gameTypeId': 2,
#    'gamesPlayed': 3,
#    'goals': 0,
#    'leagueAbbrev': 'WHL',
#    'pim': 4,
#    'plusMinus': 2,
#    'points': 1,
#    'powerPlayGoals': 0,
#    'season': 20102011,
#    'sequence': 2,
#    'shorthandedGoals': 0,
#    'teamName': {'default': 'Kelowna'}},
#   {'assists': 0,
#    'gameTypeId': 3,
#    'gamesPlayed': 6,
#    'goals': 2,
#    'leagueAbbrev': 'MMHL',
#    'pim': 10,
#    'points': 2,
#    'season': 20102011,
#    'sequence': 1,
#    'teamName': {'default': 'Wpg. Wild'}},
#   {'assists': 0,
#    'gameTypeId': 3,
#    'gamesPlayed': 1,
#    'goals': 0,
#    'leagueAbbrev': 'WHL',
#    'pim': 0,
#    'plusMinus': 0,
#    'points': 0,
#    'powerPlayGoals': 0,
#    'season': 20102011,
#    'sequence': 2,
#    'shorthandedGoals': 0,
#    'teamName': {'default': 'Kelowna'}},
#   {'assists': 13,
#    'gameTypeId': 2,
#    'gamesPlayed': 57,
#    'goals': 8,
#    'leagueAbbrev': 'WHL',
#    'pim': 39,
#    'plusMinus': 3,
#    'points': 21,
#    'powerPlayGoals': 4,
#    'season': 20112012,
#    'sequence': 1,
#    'shorthandedGoals': 1,
#    'teamName': {'default': 'Kelowna'}},
#   {'assists': 0,
#    'gameTypeId': 3,
#    'gamesPlayed': 4,
#    'goals': 1,
#    'leagueAbbrev': 'WHL',
#    'pim': 4,
#    'plusMinus': -1,
#    'points': 1,
#    'powerPlayGoals': 0,
#    'season': 20112012,
#    'sequence': 1,
#    'shorthandedGoals': 0,
#    'teamName': {'default': 'Kelowna'}},
#   {'assists': 18,
#    'gameTypeId': 2,
#    'gamesPlayed': 69,
#    'goals': 12,
#    'leagueAbbrev': 'WHL',
#    'pim': 75,
#    'plusMinus': 41,
#    'points': 30,
#    'powerPlayGoals': 3,
#    'season': 20122013,
#    'sequence': 1,
#    'shorthandedGoals': 0,
#    'teamName': {'default': 'Kelowna'}},
#   {'assists': 2,
#    'gameTypeId': 2,
#    'gameWinningGoals': 0,
#    'gamesPlayed': 7,
#    'goals': 2,
#    'leagueAbbrev': 'WJ18-A',
#    'pim': 6,
#    'plusMinus': 3,
#    'points': 4,
#    'powerPlayGoals': 1,
#    'season': 20122013,
#    'sequence': 2,
#    'shootingPctg': 11.11,
#    'shorthandedGoals': 0,
#    'shots': 18,
#    'teamName': {'default': 'Canada',
#     'cs': 'Kanada',
#     'de': 'Kanada',
#     'fi': 'Kanada',
#     'sk': 'Kanada',
#     'sv': 'Kanada'}},
#   {'assists': 4,
#    'gameTypeId': 3,
#    'gamesPlayed': 11,
#    'goals': 0,
#    'leagueAbbrev': 'WHL',
#    'pim': 14,
#    'plusMinus': -3,
#    'points': 4,
#    'powerPlayGoals': 0,
#    'season': 20122013,
#    'sequence': 1,
#    'shorthandedGoals': 0,
#    'teamName': {'default': 'Kelowna'}},
#   {'assists': 39,
#    'gameTypeId': 2,
#    'gamesPlayed': 72,
#    'goals': 21,
#    'leagueAbbrev': 'WHL',
#    'pim': 93,
#    'plusMinus': 44,
#    'points': 60,
#    'powerPlayGoals': 6,
#    'season': 20132014,
#    'sequence': 1,
#    'shorthandedGoals': 0,
#    'teamName': {'default': 'Kelowna'}},
#   {'assists': 9,
#    'gameTypeId': 3,
#    'gamesPlayed': 14,
#    'goals': 5,
#    'leagueAbbrev': 'WHL',
#    'pim': 14,
#    'plusMinus': 8,
#    'points': 14,
#    'powerPlayGoals': 0,
#    'season': 20132014,
#    'sequence': 1,
#    'shorthandedGoals': 1,
#    'teamName': {'default': 'Kelowna'}},
#   {'assists': 3,
#    'gameTypeId': 2,
#    'gameWinningGoals': 0,
#    'gamesPlayed': 7,
#    'goals': 1,
#    'leagueAbbrev': 'WJC-A',
#    'pim': 2,
#    'plusMinus': 8,
#    'points': 4,
#    'powerPlayGoals': 1,
#    'season': 20142015,
#    'sequence': 1,
#    'shorthandedGoals': 0,
#    'shots': 17,
#    'teamName': {'default': 'Canada',
#     'cs': 'Kanada',
#     'de': 'Kanada',
#     'fi': 'Kanada',
#     'sk': 'Kanada',
#     'sv': 'Kanada'}},
#   {'assists': 43,
#    'gameTypeId': 2,
#    'gameWinningGoals': 3,
#    'gamesPlayed': 58,
#    'goals': 17,
#    'leagueAbbrev': 'WHL',
#    'pim': 66,
#    'plusMinus': 38,
#    'points': 60,
#    'powerPlayGoals': 6,
#    'season': 20142015,
#    'sequence': 2,
#    'shorthandedGoals': 2,
#    'teamName': {'default': 'Kelowna'}},
#   {'assists': 12,
#    'gameTypeId': 3,
#    'gameWinningGoals': 0,
#    'gamesPlayed': 19,
#    'goals': 7,
#    'leagueAbbrev': 'WHL',
#    'pim': 24,
#    'plusMinus': 16,
#    'points': 19,
#    'powerPlayGoals': 2,
#    'season': 20142015,
#    'sequence': 1,
#    'shorthandedGoals': 2,
#    'teamName': {'default': 'Kelowna'}},
#   {'assists': 5,
#    'gameTypeId': 3,
#    'gameWinningGoals': 0,
#    'gamesPlayed': 5,
#    'goals': 1,
#    'leagueAbbrev': 'M-Cup',
#    'pim': 10,
#    'plusMinus': 1,
#    'points': 6,
#    'powerPlayGoals': 0,
#    'season': 20142015,
#    'sequence': 5,
#    'shootingPctg': 4.5,
#    'shorthandedGoals': 0,
#    'shots': 22,
#    'teamName': {'default': 'Kelowna'}},
#   {'assists': 25,
#    'gameTypeId': 2,
#    'gameWinningGoals': 0,
#    'gamesPlayed': 70,
#    'goals': 4,
#    'leagueAbbrev': 'AHL',
#    'pim': 58,
#    'plusMinus': 22,
#    'points': 29,
#    'powerPlayGoals': 1,
#    'season': 20152016,
#    'sequence': 1,
#    'shootingPctg': 4.3,
#    'shorthandedGoals': 0,
#    'shots': 94,
#    'teamName': {'default': 'Hershey'}},
#   {'assists': 6,
#    'gameTypeId': 3,
#    'gameWinningGoals': 0,
#    'gamesPlayed': 21,
#    'goals': 0,
#    'leagueAbbrev': 'AHL',
#    'pim': 35,
#    'plusMinus': -3,
#    'points': 6,
#    'powerPlayGoals': 0,
#    'season': 20152016,
#    'sequence': 1,
#    'shootingPctg': 0.0,
#    'shorthandedGoals': 0,
#    'shots': 23,
#    'teamName': {'default': 'Hershey'}},
#   {'assists': 11,
#    'gameTypeId': 2,
#    'gamesPlayed': 34,
#    'goals': 3,
#    'leagueAbbrev': 'AHL',
#    'pim': 28,
#    'plusMinus': 6,
#    'points': 14,
#    'season': 20162017,
#    'sequence': 997,
#    'teamName': {'default': 'Hershey Bears'}},
#   {'assists': 2,
#    'gameTypeId': 3,
#    'gamesPlayed': 10,
#    'goals': 2,
#    'leagueAbbrev': 'AHL',
#    'pim': 6,
#    'plusMinus': 4,
#    'points': 4,
#    'season': 20162017,
#    'sequence': 997,
#    'teamName': {'default': 'Hershey Bears'}},
#   {'assists': 12,
#    'avgToi': '13:42',
#    'faceoffWinningPctg': 0.0,
#    'gameTypeId': 2,
#    'gameWinningGoals': 0,
#    'gamesPlayed': 51,
#    'goals': 0,
#    'leagueAbbrev': 'NHL',
#    'otGoals': 0,
#    'pim': 24,
#    'plusMinus': -3,
#    'points': 12,
#    'powerPlayGoals': 0,
#    'powerPlayPoints': 0,
#    'season': 20172018,
#    'sequence': 1,
#    'shootingPctg': 0.0,
#    'shorthandedGoals': 0,
#    'shorthandedPoints': 0,
#    'shots': 47,
#    'teamName': {'default': 'Washington Capitals',
#     'fr': 'Capitals de Washington'}},
#   {'assists': 6,
#    'gameTypeId': 2,
#    'gamesPlayed': 9,
#    'goals': 2,
#    'leagueAbbrev': 'AHL',
#    'pim': 6,
#    'plusMinus': -1,
#    'points': 8,
#    'season': 20172018,
#    'sequence': 997,
#    'teamName': {'default': 'Hershey Bears'}},
#   {'assists': 5,
#    'avgToi': '13:44',
#    'faceoffWinningPctg': 0.0,
#    'gameTypeId': 2,
#    'gameWinningGoals': 1,
#    'gamesPlayed': 33,
#    'goals': 1,
#    'leagueAbbrev': 'NHL',
#    'otGoals': 0,
#    'pim': 38,
#    'plusMinus': 3,
#    'points': 6,
#    'powerPlayGoals': 0,
#    'powerPlayPoints': 0,
#    'season': 20182019,
#    'sequence': 1,
#    'shootingPctg': 0.0294,
#    'shorthandedGoals': 0,
#    'shorthandedPoints': 0,
#    'shots': 34,
#    'teamName': {'default': 'Washington Capitals',
#     'fr': 'Capitals de Washington'}},
#   {'assists': 3,
#    'avgToi': '18:11',
#    'faceoffWinningPctg': 0.0,
#    'gameTypeId': 2,
#    'gameWinningGoals': 0,
#    'gamesPlayed': 17,
#    'goals': 1,
#    'leagueAbbrev': 'NHL',
#    'otGoals': 0,
#    'pim': 8,
#    'plusMinus': -4,
#    'points': 4,
#    'powerPlayGoals': 0,
#    'powerPlayPoints': 0,
#    'season': 20182019,
#    'sequence': 2,
#    'shootingPctg': 0.0714,
#    'shorthandedGoals': 0,
#    'shorthandedPoints': 0,
#    'shots': 14,
#    'teamName': {'default': 'Detroit Red Wings', 'fr': 'Red Wings de Detroit'}},
#   {'assists': 14,
#    'avgToi': '17:54',
#    'faceoffWinningPctg': 0.0,
#    'gameTypeId': 2,
#    'gameWinningGoals': 0,
#    'gamesPlayed': 53,
#    'goals': 3,
#    'leagueAbbrev': 'NHL',
#    'otGoals': 0,
#    'pim': 34,
#    'plusMinus': -16,
#    'points': 17,
#    'powerPlayGoals': 0,
#    'powerPlayPoints': 1,
#    'season': 20192020,
#    'sequence': 1,
#    'shootingPctg': 0.043,
#    'shorthandedGoals': 0,
#    'shorthandedPoints': 0,
#    'shots': 70,
#    'teamName': {'default': 'Detroit Red Wings', 'fr': 'Red Wings de Detroit'}},
#   {'assists': 1,
#    'gameTypeId': 2,
#    'gamesPlayed': 1,
#    'goals': 0,
#    'leagueAbbrev': 'AHL',
#    'pim': 2,
#    'plusMinus': 1,
#    'points': 1,
#    'season': 20192020,
#    'sequence': 987,
#    'teamName': {'default': 'Grand Rapids Griffins'}},
#   {'assists': 1,
#    'avgToi': '11:08',
#    'faceoffWinningPctg': 0.0,
#    'gameTypeId': 2,
#    'gameWinningGoals': 0,
#    'gamesPlayed': 2,
#    'goals': 0,
#    'leagueAbbrev': 'NHL',
#    'otGoals': 0,
#    'pim': 0,
#    'plusMinus': 1,
#    'points': 1,
#    'powerPlayGoals': 0,
#    'powerPlayPoints': 0,
#    'season': 20202021,
#    'sequence': 1,
#    'shootingPctg': 0.0,
#    'shorthandedGoals': 0,
#    'shorthandedPoints': 0,
#    'shots': 0,
#    'teamName': {'default': 'Chicago Blackhawks',
#     'fr': 'Blackhawks de Chicago'}},
#   {'assists': 0,
#    'gameTypeId': 2,
#    'gamesPlayed': 2,
#    'goals': 0,
#    'leagueAbbrev': 'AHL',
#    'pim': 6,
#    'plusMinus': -2,
#    'points': 0,
#    'season': 20202021,
#    'sequence': 8267,
#    'teamName': {'default': 'Rockford IceHogs'}},
#   {'assists': 0,
#    'avgToi': '15:44',
#    'faceoffWinningPctg': 0.0,
#    'gameTypeId': 2,
#    'gameWinningGoals': 0,
#    'gamesPlayed': 2,
#    'goals': 0,
#    'leagueAbbrev': 'NHL',
#    'otGoals': 0,
#    'pim': 0,
#    'plusMinus': -3,
#    'points': 0,
#    'powerPlayGoals': 0,
#    'powerPlayPoints': 0,
#    'season': 20212022,
#    'sequence': 1,
#    'shootingPctg': 0.0,
#    'shorthandedGoals': 0,
#    'shorthandedPoints': 0,
#    'shots': 0,
#    'teamName': {'default': 'Vancouver Canucks', 'fr': 'Canucks de Vancouver'}},
#   {'assists': 20,
#    'gameTypeId': 2,
#    'gamesPlayed': 53,
#    'goals': 8,
#    'leagueAbbrev': 'AHL',
#    'pim': 80,
#    'plusMinus': 18,
#    'points': 28,
#    'season': 20212022,
#    'sequence': 33767,
#    'teamName': {'default': 'Abbotsford Canucks'}},
#   {'assists': 0,
#    'gameTypeId': 3,
#    'gamesPlayed': 2,
#    'goals': 0,
#    'leagueAbbrev': 'AHL',
#    'pim': 2,
#    'plusMinus': -2,
#    'points': 0,
#    'season': 20212022,
#    'sequence': 33767,
#    'teamName': {'default': 'Abbotsford Canucks'}},
#   {'assists': 9,
#    'gameTypeId': 2,
#    'gamesPlayed': 35,
#    'goals': 4,
#    'leagueAbbrev': 'AHL',
#    'pim': 24,
#    'plusMinus': -3,
#    'points': 13,
#    'season': 20222023,
#    'sequence': 222817,
#    'teamName': {'default': 'Laval Rocket'}},
#   {'assists': 3,
#    'gameTypeId': 2,
#    'gamesPlayed': 21,
#    'goals': 2,
#    'leagueAbbrev': 'KHL',
#    'pim': 4,
#    'plusMinus': -3,
#    'points': 5,
#    'season': 20232024,
#    'sequence': 2444,
#    'teamName': {'default': 'Torpedo Nizhny Novgorod'}},
#   {'assists': 2,
#    'gameTypeId': 2,
#    'gamesPlayed': 8,
#    'goals': 0,
#    'leagueAbbrev': 'KHL',
#    'pim': 15,
#    'plusMinus': 0,
#    'points': 2,
#    'season': 20232024,
#    'sequence': 17224,
#    'teamName': {'default': 'Dinamo Minsk'}},
#   {'assists': 5,
#    'gameTypeId': 2,
#    'gamesPlayed': 22,
#    'goals': 2,
#    'leagueAbbrev': 'KHL',
#    'pim': 31,
#    'plusMinus': -1,
#    'points': 7,
#    'season': 20232024,
#    'sequence': 17234,
#    'teamName': {'default': 'Traktor Chelyabinsk'}}],
#  'awards': [{'trophy': {'default': 'Stanley Cup'},
#    'seasons': [{'assists': 12,
#      'blockedShots': 42,
#      'gameTypeId': 2,
#      'gamesPlayed': 51,
#      'goals': 0,
#      'hits': 48,
#      'pim': 24,
#      'plusMinus': -3,
#      'points': 12,
#      'seasonId': 20172018}]}]}

# %%
(pbp_data.get('firstName').get('default') + " " + pbp_data.get('lastName').get('default')).upper()
# Out:
# 'MADISON BOWEY'

# %% [markdown]
# ## Player Names and IDs Dictionary

# %%
def get_away_roster(game_id):
    
    url = 'https://api-web.nhle.com/v1/gamecenter/{}/boxscore'.format(game_id)
    
    try:
        data = requests.get(url)
        boxscore = data.json()
        
    except Exception as e:
        print('URL does not exist for Game_Id {}'.format(game_id))
        return None
        
    else:
        away_roster = {}
        forwards = boxscore.get('playerByGameStats').get('awayTeam').get('forwards')
        defense = boxscore.get('playerByGameStats').get('awayTeam').get('defense')
        goalies = boxscore.get('playerByGameStats').get('awayTeam').get('goalies')

        for spot in forwards:
            url = 'https://api-web.nhle.com/v1/player/{}/landing'.format(spot.get('playerId'))
            playerInfo = requests.get(url)
            playerInfo = playerInfo.json()
            away_roster.update({ spot.get('playerId') : (playerInfo.get('firstName').get('default') + " " + playerInfo.get('lastName').get('default')).upper()})
        
        for spot in defense:
            url = 'https://api-web.nhle.com/v1/player/{}/landing'.format(spot.get('playerId'))
            playerInfo = requests.get(url)
            playerInfo = playerInfo.json()
            away_roster.update({spot.get('playerId') : (playerInfo.get('firstName').get('default') + " " + playerInfo.get('lastName').get('default')).upper()})
        
        for spot in goalies:
            url = 'https://api-web.nhle.com/v1/player/{}/landing'.format(spot.get('playerId'))
            playerInfo = requests.get(url)
            playerInfo = playerInfo.json()
            away_roster.update({spot.get('playerId') : (playerInfo.get('firstName').get('default') + " " + playerInfo.get('lastName').get('default')).upper()})
                
        return away_roster

# %%
# Testing
# get_away_roster(game_id)

# %%
def get_home_roster(game_id):
    
    url = 'https://api-web.nhle.com/v1/gamecenter/{}/boxscore'.format(game_id)
    
    try:
        data = requests.get(url)
        boxscore = data.json()
        
    except Exception as e:
        print('URL does not exist for Game_Id {}'.format(game_id))
        return None
        
    else:
        home_roster = {}
        forwards = boxscore.get('playerByGameStats').get('homeTeam').get('forwards')
        defense = boxscore.get('playerByGameStats').get('homeTeam').get('defense')
        goalies = boxscore.get('playerByGameStats').get('homeTeam').get('goalies')

        for spot in forwards:
            url = 'https://api-web.nhle.com/v1/player/{}/landing'.format(spot.get('playerId'))
            playerInfo = requests.get(url)
            playerInfo = playerInfo.json()
            home_roster.update({ spot.get('playerId') : (playerInfo.get('firstName').get('default') + " " + playerInfo.get('lastName').get('default')).upper()})
        
        for spot in defense:
            url = 'https://api-web.nhle.com/v1/player/{}/landing'.format(spot.get('playerId'))
            playerInfo = requests.get(url)
            playerInfo = playerInfo.json()
            home_roster.update({ spot.get('playerId') : (playerInfo.get('firstName').get('default') + " " + playerInfo.get('lastName').get('default')).upper()})
        
        for spot in goalies:
            url = 'https://api-web.nhle.com/v1/player/{}/landing'.format(spot.get('playerId'))
            playerInfo = requests.get(url)
            playerInfo = playerInfo.json()
            home_roster.update({ spot.get('playerId') : (playerInfo.get('firstName').get('default') + " " + playerInfo.get('lastName').get('default')).upper()})
                
        return home_roster

# %%
# Testing
# get_home_roster(game_id)

# %%
def get_game_roster(game_id):
    
    away_roster = get_away_roster(game_id)
    home_roster = get_home_roster(game_id)
    
    game_roster = away_roster.update(home_roster)
    
    return away_roster

# %%
# Testing
# get_game_roster(2023020001)

# %% [markdown]
# <br>
#
# ## Getting Player Positions
#
# For the purposes of my model, skaters are classified as either forwards or defencemen with no differentiation between centers or wingers.

# %%
def get_away_positions(game_id):
    
    url = 'https://api-web.nhle.com/v1/gamecenter/{}/boxscore'.format(game_id)
    
    try:
        data = requests.get(url)
        boxscore = data.json()
        
    except Exception as e:
        print('URL does not exist for Game_Id {}'.format(game_id))
        return None
        
    else:
        away_roster = {}
        forwards = boxscore.get('playerByGameStats').get('awayTeam').get('forwards')
        defense = boxscore.get('playerByGameStats').get('awayTeam').get('defense')
        goalies = boxscore.get('playerByGameStats').get('awayTeam').get('goalies')

        for spot in forwards:
            url = 'https://api-web.nhle.com/v1/player/{}/landing'.format(spot.get('playerId'))
            playerInfo = requests.get(url)
            playerInfo = playerInfo.json()
            away_roster.update({ spot.get('playerId') : 'F'})
        
        for spot in defense:
            url = 'https://api-web.nhle.com/v1/player/{}/landing'.format(spot.get('playerId'))
            playerInfo = requests.get(url)
            playerInfo = playerInfo.json()
            away_roster.update({spot.get('playerId') : 'D'})
        
        for spot in goalies:
            url = 'https://api-web.nhle.com/v1/player/{}/landing'.format(spot.get('playerId'))
            playerInfo = requests.get(url)
            playerInfo = playerInfo.json()
            away_roster.update({spot.get('playerId') : 'G'})
                
        return away_roster

# %%
# Testing
# get_away_positions(2023020001)

# %%
def get_home_positions(game_id):
    
    url = 'https://api-web.nhle.com/v1/gamecenter/{}/boxscore'.format(game_id)
    
    try:
        data = requests.get(url)
        boxscore = data.json()
        
    except Exception as e:
        print('URL does not exist for Game_Id {}'.format(game_id))
        return None
        
    else:
        home_roster = {}
        forwards = boxscore.get('playerByGameStats').get('homeTeam').get('forwards')
        defense = boxscore.get('playerByGameStats').get('homeTeam').get('defense')
        goalies = boxscore.get('playerByGameStats').get('homeTeam').get('goalies')

        for spot in forwards:
            url = 'https://api-web.nhle.com/v1/player/{}/landing'.format(spot.get('playerId'))
            playerInfo = requests.get(url)
            playerInfo = playerInfo.json()
            home_roster.update({ spot.get('playerId') : 'F'})
        
        for spot in defense:
            url = 'https://api-web.nhle.com/v1/player/{}/landing'.format(spot.get('playerId'))
            playerInfo = requests.get(url)
            playerInfo = playerInfo.json()
            home_roster.update({spot.get('playerId') : 'D'})
        
        for spot in goalies:
            url = 'https://api-web.nhle.com/v1/player/{}/landing'.format(spot.get('playerId'))
            playerInfo = requests.get(url)
            playerInfo = playerInfo.json()
            home_roster.update({spot.get('playerId') : 'G'})
                
        return home_roster

# %%
# Testing
# get_home_positions(2023020001)

# %%
def get_game_positions(game_id):
    
    away_positions = get_away_positions(game_id)
    home_positions = get_home_positions(game_id)
    
    game_positions = away_positions.update(home_positions)
    
    return away_positions

# %%
# Testing
# get_game_positions(2023020001)

# %% [markdown]
# <br>
#
# ### Getting Goalies (Helper Function)

# %%
def get_goalies_id(game_id):
    
    url = 'https://api-web.nhle.com/v1/gamecenter/{}/boxscore'.format(game_id)
    
    try:
        data = requests.get(url)
        boxscore = data.json()
        
    except Exception as e:
        print('URL does not exist for Game_Id {}'.format(game_id))
        return None
        
    else:
        goalies = {}
        away_goalies = boxscore.get('playerByGameStats').get('awayTeam').get('goalies')
        home_goalies = boxscore.get('playerByGameStats').get('homeTeam').get('goalies')
        
        for spot in away_goalies:
            url = 'https://api-web.nhle.com/v1/player/{}/landing'.format(spot.get('playerId'))
            playerInfo = requests.get(url)
            playerInfo = playerInfo.json()
            goalies.update({ spot.get('playerId') : (playerInfo.get('firstName').get('default') + " " + playerInfo.get('lastName').get('default')).upper()})
            
        for spot in home_goalies:
            url = 'https://api-web.nhle.com/v1/player/{}/landing'.format(spot.get('playerId'))
            playerInfo = requests.get(url)
            playerInfo = playerInfo.json()
            goalies.update({ spot.get('playerId') : (playerInfo.get('firstName').get('default') + " " + playerInfo.get('lastName').get('default')).upper()})
                
        return goalies

# %%
# Tester
# get_goalies_id(2023020105)

# %% [markdown]
# <br>

# %% [markdown]
# ### Known Event typeCodes

# %%
typeCodes = {502 : 'FACEOFF', 503 : 'HIT', 504 : 'GIVEAWAY', 505 : 'GOAL', 506 : 'SHOT_ON_GOAL', 507 : 'MISSED_SHOT',
             508 : 'BLOCKED_SHOT', 509 : 'PENALTY', 516 : 'STOPPAGE', 520 : 'PERIOD_START', 521 : 'PERIOD_END',
             523 : 'SHOOTOUT_COMPLETE', 524 : 'GAME_END', 525 : 'TAKEAWAY', 535 : 'DELAYED_PENALTY', 
             537 : 'FAILED_SHOT_ATTEMPT'}

shotCodes = [505,506,507,508]

# %% [markdown]
# <br>

# %% [markdown]
# ## Play-By-Play DataFrame
#
# This combines the play-by-play and shift data. Most of the chosen columns were inspired by Harry Shomer's public hockey scraper that I had used previously.

# %%
def parse_event(play_dict):
    
    event_dict_keys = ['Period','Event_tc','Event','Time_Elapsed','Strength','Ev_Zone','Type','Ev_Team','p1_name','p1_ID',
                       'p2_name','p2_ID','p3_name','p3_ID','xC','yC']
    
    event_dict = dict()
    
    # Common play items across all plays
    event_dict['Period'] = play_dict['period']
    event_dict['Event_tc'] = play_dict['typeCode']
    event_dict['Event'] = play_dict['typeDescKey'].upper()
    event_dict['Time_Elapsed'] = play_dict['timeRemaining']
    event_dict['Strength'] = play_dict['situationCode']
    event_dict['sort_order'] = play_dict['sortOrder']
      
    # Below is applicable for FACEOFF, HIT, GIVEAWAY, GOAL, SHOT_ON_GOAL, MISSED_SHOT, BLOCKED_SHOT, PENALTY, TAKEAWAY, DELAYED_PENALTY    
    if 'details' in play_dict.keys(): 
        if 'zoneCode' in play_dict['details'].keys():
            event_dict['Ev_Zone'] = play_dict['details']['zoneCode']
        if 'xCoord' in play_dict['details'].keys():
            event_dict['xC'] = play_dict['details']['xCoord']
            event_dict['yC'] = play_dict['details']['yCoord']
        
        if event_dict['Event_tc'] == 502: # Faceoffs
            if 'winningPlayerId' in play_dict['details'].keys():
                event_dict['p1_ID'] = play_dict['details']['winningPlayerId']
                event_dict['Ev_Team'] = play_dict['details']['eventOwnerTeamId']
            if 'losingPlayerId' in play_dict['details'].keys():
                event_dict['p2_ID'] = play_dict['details']['losingPlayerId']
            
        if event_dict['Event_tc'] == 503: # Hits
            if 'hittingPlayerId' in play_dict['details'].keys():
                event_dict['p1_ID'] = play_dict['details']['hittingPlayerId']
                event_dict['Ev_Team'] = play_dict['details']['eventOwnerTeamId']
            if 'hitteePlayerId' in play_dict['details'].keys():
                event_dict['p2_ID'] = play_dict['details']['hitteePlayerId']
  
        if event_dict['Event_tc'] == 504: # Giveaways
            if 'playerId' in play_dict['details'].keys():
                event_dict['p1_ID'] = play_dict['details']['playerId']
                event_dict['Ev_Team'] = play_dict['details']['eventOwnerTeamId']
            
        if event_dict['Event_tc'] in [505,506,507,508]: # Goals, Shots_On_Goal, Missed_Shots, Blocked_Shots
            if 'scoringPlayerId' in play_dict['details'].keys():
                event_dict['p1_ID'] = play_dict['details']['scoringPlayerId']
            if 'shootingPlayerId' in play_dict['details'].keys():
                event_dict['p1_ID'] = play_dict['details']['shootingPlayerId']
                event_dict['Ev_Team'] = play_dict['details']['eventOwnerTeamId']
            if 'assist1PlayerId' in play_dict['details'].keys():
                event_dict['p2_ID'] = play_dict['details']['assist1PlayerId']
            if 'assist2PlayerId' in play_dict['details'].keys():
                event_dict['p3_ID'] = play_dict['details']['assist2PlayerId']
            if 'blockingPlayerId' in play_dict['details'].keys():
                event_dict['p2_ID'] = play_dict['details']['blockingPlayerId']
            if 'type' in play_dict['details'].keys():
                event_dict['Type'] = play_dict['details']['shotType'].upper()
            if 'homeScore' in play_dict['details'].keys():
                event_dict['Home_Score'] = play_dict['details']['homeScore']
                event_dict['Away_Score'] = play_dict['details']['awayScore']
            
        if event_dict['Event_tc'] == 509: # Penalties
            if 'committedByPlayerId' in play_dict['details'].keys():
                event_dict['p1_ID'] = play_dict['details']['committedByPlayerId']
                event_dict['Ev_Team'] = play_dict['details']['eventOwnerTeamId']
            if 'drawnByPlayerId' in play_dict['details'].keys():
                event_dict['p2_ID'] = play_dict['details']['drawnByPlayerId']
            if 'descKey' in play_dict['details'].keys():
                event_dict['Type'] = play_dict['details']['typeCode'] + ' for ' + play_dict['details']['descKey'].upper()
            
        if event_dict['Event_tc'] == 525: # Takeaways
            if 'playerId' in play_dict['details'].keys():
                event_dict['p1_ID'] = play_dict['details']['playerId']
                event_dict['Ev_Team'] = play_dict['details']['eventOwnerTeamId']
            
        if event_dict['Event_tc'] == 535: # Delayed Penalties
            if 'eventOwnerTeamId' in play_dict['details'].keys():
                event_dict['Ev_Team'] = play_dict['details']['eventOwnerTeamId']
            
        # Failed_Shot_Attempts?
        
    return event_dict

# %%
def get_pbp_improvement_beta(game_id):
    
    url = 'https://api-web.nhle.com/v1/gamecenter/{}/play-by-play'.format(game_id)
    
    try:
        pbp = requests.get('https://api-web.nhle.com/v1/gamecenter/'+str(game_id)+'/play-by-play')
        pbp_data = pbp.json()
    
    except Exception as e:
        print('Unable to get play-by-play for Game_Id {}'.format(game_id))
        return None
        
    else:
        plays = pbp_data['plays']
        events = [parse_event(play) for play in plays]
        pbp_df = pd.DataFrame(events)
        
        awayTeam_Id, homeTeam_Id, game_roster = pbp_data.get('awayTeam').get('id'), pbp_data.get('homeTeam').get('id'), get_game_roster(game_id)
        goalie_ids = get_goalies_id(game_id)
        NoneType = type(None)
    
        away_on_ice_player_ids = ['awayPlayer1_id','awayPlayer2_id','awayPlayer3_id','awayPlayer4_id','awayPlayer5_id',
                                  'awayPlayer6_id']
        home_on_ice_player_ids = ['homePlayer1_id','homePlayer2_id','homePlayer3_id','homePlayer4_id','homePlayer5_id',
                                  'homePlayer6_id']
    
        cols = ['Game_Id','Date','Period','Event_tc','Event','Time_Elapsed','Strength','Ev_Zone','Type','Ev_Team','Away_Team',
                'Home_Team','p1_name','p1_ID','p2_name','p2_ID','p3_name','p3_ID','awayPlayer1','awayPlayer1_id','awayPlayer2',
                'awayPlayer2_id','awayPlayer3','awayPlayer3_id','awayPlayer4','awayPlayer4_id','awayPlayer5','awayPlayer5_id',
                'awayPlayer6','awayPlayer6_id','homePlayer1','homePlayer1_id','homePlayer2','homePlayer2_id','homePlayer3',
                'homePlayer3_id','homePlayer4','homePlayer4_id','homePlayer5','homePlayer5_id','homePlayer6','homePlayer6_id',
                'Away_Score','Home_Score','Away_Goalie','Away_Goalie_Id','Home_Goalie','Home_Goalie_Id','xC','yC']
        
        pbp_df['Away_Team'] = pbp_data.get('awayTeam').get('abbrev')
        pbp_df['Home_Team'] = pbp_data.get('homeTeam').get('abbrev')
        for col in cols:
            if col not in pbp_df.columns:
                pbp_df[col] = None
        
        # Adding Shift Data
        shifts = requests.get('https://api.nhle.com/stats/rest/en/shiftcharts?cayenneExp=gameId={}'.format(game_id))

        shift_data = shifts.json()
        shift_data.get('data')

        homePlayerList = ['homePlayer1_id','homePlayer2_id','homePlayer3_id','homePlayer4_id','homePlayer5_id','homePlayer6_id']
        homePlayerList_names = ['homePlayer1','homePlayer2','homePlayer3','homePlayer4','homePlayer5','homePlayer6']
        awayPlayerList = ['awayPlayer1_id','awayPlayer2_id','awayPlayer3_id','awayPlayer4_id','awayPlayer5_id','awayPlayer6_id']
        awayPlayerList_names = ['awayPlayer1','awayPlayer2','awayPlayer3','awayPlayer4','awayPlayer5','awayPlayer6']

        for i in range(len(shift_data.get('data'))):

            shift = shift_data.get('data')[i]

            period = shift.get('period')
            shift_start = datetime.strptime(shift.get('startTime'),'%M:%S')
            shift_end = datetime.strptime(shift.get('endTime'),'%M:%S')

            for j in range(len(pbp_df)):

                time_elapsed = datetime.strptime(pbp_df.at[j,'Time_Elapsed'],'%M:%S')

                awayPlayerList_loop = [pbp_df.at[j,'awayPlayer1_id'],pbp_df.at[j,'awayPlayer2_id'],pbp_df.at[j,'awayPlayer3_id'],
                                       pbp_df.at[j,'awayPlayer4_id'],pbp_df.at[j,'awayPlayer5_id'],pbp_df.at[j,'awayPlayer6_id']]
                homePlayerList_loop = [pbp_df.at[j,'homePlayer1_id'],pbp_df.at[j,'homePlayer2_id'],pbp_df.at[j,'homePlayer3_id'],
                                       pbp_df.at[j,'homePlayer4_id'],pbp_df.at[j,'homePlayer5_id'],pbp_df.at[j,'homePlayer6_id']]

                if (period == pbp_df.at[j,'Period']) & (shift_start <= time_elapsed < shift_end):

                    if shift.get('teamId') == awayTeam_Id:
                        if shift.get('playerId') not in awayPlayerList_loop:
                            for k in range(len(awayPlayerList)):
                                if pd.isna(pbp_df.at[j,awayPlayerList[k]]) == True:
                                    pbp_df.at[j,awayPlayerList[k]] = shift.get('playerId')
                                    pbp_df.at[j,awayPlayerList_names[k]] = game_roster.get(shift.get('playerId'))
                                    break

                    if shift.get('teamId') == homeTeam_Id:
                        if shift.get('playerId') not in homePlayerList_loop:
                            for k in range(len(homePlayerList)):
                                if pd.isna(pbp_df.at[j,homePlayerList[k]]) == True:
                                    pbp_df.at[j,homePlayerList[k]] = shift.get('playerId')
                                    pbp_df.at[j,homePlayerList_names[k]] = game_roster.get(shift.get('playerId'))
                                    break
        
        # Adding goalies to blocked shots
        for i in range(len(pbp_df)):
            for j in range(len(away_on_ice_player_ids)):
                for g_id in goalie_ids:
                    if g_id == pbp_df.at[i,away_on_ice_player_ids[j]]:
                        pbp_df.at[i,'Away_Goalie_Id'] = g_id
                        pbp_df.at[i,'Away_Goalie'] = game_roster.get(g_id)
                        break
            for j in range(len(home_on_ice_player_ids)):
                for g_id in goalie_ids:
                    if g_id == pbp_df.at[i,home_on_ice_player_ids[j]]:
                        pbp_df.at[i,'Home_Goalie_Id'] = g_id
                        pbp_df.at[i,'Home_Goalie'] = game_roster.get(g_id)
                        break
                        
        
        return pbp_df

# %%
# %%time

pbp = get_pbp_improvement_beta(game_id)
pbp
# Out:
# CPU times: total: 46.9 ms
# Wall time: 331 ms
#      Period  Event_tc         Event Time_Elapsed Strength  sort_order Ev_Zone  \
# 0         1       520  PERIOD-START        20:00     1551          10     NaN
# 1         1       502       FACEOFF        20:00     1551          11       N
# 2         1       503           HIT        19:19     1551          19       O
# 3         1       525      TAKEAWAY        19:14     1551          21       D
# 4         1       506  SHOT-ON-GOAL        19:09     1551          22       O
# ..      ...       ...           ...          ...      ...         ...     ...
# 285       3       516      STOPPAGE        00:14     0651         788     NaN
# 286       3       502       FACEOFF        00:14     0651         789       D
# 287       3       508  BLOCKED-SHOT        00:09     0651         790       D
# 288       3       521    PERIOD-END        00:00     0651         791     NaN
# 289       3       524      GAME-END        00:00     0651         795     NaN
#
#        xC    yC      p1_ID  Ev_Team      p2_ID Type  p3_ID  Home_Score  \
# 0     NaN   NaN        NaN      NaN        NaN  NaN    NaN         NaN
# 1     0.0   0.0  8473994.0     25.0  8480012.0  NaN    NaN         NaN
# 2   -95.0 -27.0  8476468.0     23.0  8480036.0  NaN    NaN         NaN
# 3    50.0   6.0  8476468.0     23.0        NaN  NaN    NaN         NaN
# 4   -57.0  -4.0  8478444.0     23.0        NaN  NaN    NaN         NaN
# ..    ...   ...        ...      ...        ...  ...    ...         ...
# 285   NaN   NaN        NaN      NaN        NaN  NaN    NaN         NaN
# 286  69.0  22.0  8476468.0     23.0  8473994.0  NaN    NaN         NaN
# 287  42.0 -35.0  8475794.0     23.0  8480012.0  NaN    NaN         NaN
# 288   NaN   NaN        NaN      NaN        NaN  NaN    NaN         NaN
# 289   NaN   NaN        NaN      NaN        NaN  NaN    NaN         NaN
#
#      Away_Score
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# ..          ...
# 285         NaN
# 286         NaN
# 287         NaN
# 288         NaN
# 289         NaN
#
# [290 rows x 16 columns]

# %% [markdown]
# <br>
#
# ### Best Current Scraper

# %%
def get_play_by_play(game_id):
    
    url = 'https://api-web.nhle.com/v1/gamecenter/{}/play-by-play'.format(game_id)
    
    try:
        pbp = requests.get('https://api-web.nhle.com/v1/gamecenter/'+str(game_id)+'/play-by-play')
        pbp_data = pbp.json()
    
    except Exception as e:
        print('Unable to get play-by-play for Game_Id {}'.format(game_id))
        
    else:
        print('Scraping Game Id',game_id) # Print status message
    
        awayTeam_Id, homeTeam_Id, game_roster = pbp_data.get('awayTeam').get('id'), pbp_data.get('homeTeam').get('id'), get_game_roster(game_id)
        goalie_ids = get_goalies_id(game_id)
        NoneType = type(None)
    
        away_on_ice_player_ids = ['awayPlayer1_id','awayPlayer2_id','awayPlayer3_id','awayPlayer4_id','awayPlayer5_id',
                                  'awayPlayer6_id']
        home_on_ice_player_ids = ['homePlayer1_id','homePlayer2_id','homePlayer3_id','homePlayer4_id','homePlayer5_id',
                                  'homePlayer6_id']
    
        cols = ['Game_Id','Date','Period','Event_tc','Event','Time_Elapsed','Strength','Ev_Zone','Type','Ev_Team','Away_Team',
                'Home_Team','p1_name','p1_ID','p2_name','p2_ID','p3_name','p3_ID','awayPlayer1','awayPlayer1_id','awayPlayer2',
                'awayPlayer2_id','awayPlayer3','awayPlayer3_id','awayPlayer4','awayPlayer4_id','awayPlayer5','awayPlayer5_id',
                'awayPlayer6','awayPlayer6_id','homePlayer1','homePlayer1_id','homePlayer2','homePlayer2_id','homePlayer3',
                'homePlayer3_id','homePlayer4','homePlayer4_id','homePlayer5','homePlayer5_id','homePlayer6','homePlayer6_id',
                'Away_Score','Home_Score','Away_Goalie','Away_Goalie_Id','Home_Goalie','Home_Goalie_Id','xC','yC']

        pbp_df = pd.DataFrame(index=np.arange(len(pbp_data.get('plays'))),columns=cols)
        
        pbp_df['Game_Id'] = pbp_data.get('id')
        pbp_df['Date'] = pbp_data.get('gameDate')
        pbp_df['Away_Team'] = pbp_data.get('awayTeam').get('abbrev')
        pbp_df['Home_Team'] = pbp_data.get('homeTeam').get('abbrev')
    
        for i in range(len(pbp_data.get('plays'))):
            
            this_play = pbp_data.get('plays')[i]
    
            pbp_df.at[i,'Period'] = this_play.get('period')
            pbp_df.at[i,'Event_tc'] = this_play.get('typeCode')
            pbp_df.at[i,'Event'] = typeCodes.get(this_play.get('typeCode'))
            pbp_df.at[i,'Time_Elapsed'] = this_play.get('timeInPeriod')
            pbp_df.at[i,'Strength'] = str(this_play.get('situationCode'))
    
            if i == 0:
                pbp_df.at[i,'Away_Score'] = 0
                pbp_df.at[i,'Home_Score'] = 0
            elif this_play.get('typeCode') != 505:
                pbp_df.at[i,'Away_Score'] = pbp_df.at[i-1,'Away_Score']
                pbp_df.at[i,'Home_Score'] = pbp_df.at[i-1,'Home_Score']
   
            if this_play.get('typeCode') in [502,503,504,505,506,507,508,509,525,537]: # If Event has xC and yC
                pbp_df.at[i,'xC'] = this_play.get('details').get('xCoord')
                pbp_df.at[i,'yC'] = this_play.get('details').get('yCoord')
                pbp_df.at[i,'Ev_Zone'] = this_play.get('details').get('zoneCode')
                if this_play.get('details').get('eventOwnerTeamId') == awayTeam_Id:
                    pbp_df.at[i,'Ev_Team'] = pbp_data.get('awayTeam').get('abbrev')
                else:
                    pbp_df.at[i,'Ev_Team'] = pbp_data.get('homeTeam').get('abbrev')
            
            if this_play.get('typeCode') == 502: # If it's a faceoff
                pbp_df.at[i,'p1_ID'] = this_play.get('details').get('winningPlayerId')
                pbp_df.at[i,'p1_name'] = game_roster.get(this_play.get('details').get('winningPlayerId'))
                pbp_df.at[i,'p2_ID'] = this_play.get('details').get('losingPlayerId')
                pbp_df.at[i,'p2_name'] = game_roster.get(this_play.get('details').get('losingPlayerId'))
        
            if this_play.get('typeCode') == 503: # If it's a hit
                pbp_df.at[i,'p1_ID'] = this_play.get('details').get('hittingPlayerId')
                pbp_df.at[i,'p1_name'] = game_roster.get(this_play.get('details').get('hittingPlayerId'))
                pbp_df.at[i,'p2_ID'] = this_play.get('details').get('hitteePlayerId')
                pbp_df.at[i,'p2_name'] = game_roster.get(this_play.get('details').get('hitteePlayerId'))
    
            if this_play.get('typeCode') == 504: # If it's a giveaway
                pbp_df.at[i,'p1_ID'] = this_play.get('details').get('playerId')
                pbp_df.at[i,'p1_name'] = game_roster.get(this_play.get('details').get('playerId'))
            
            if this_play.get('typeCode') in shotCodes: # If the play is a shot type
                if this_play.get('details').get('eventOwnerTeamId') == pbp_data.get('awayTeam').get('id'): # Away team shooting
                    pbp_df.at[i,'Home_Goalie_Id'] = this_play.get('details').get('goalieInNetId')
                    pbp_df.at[i,'Home_Goalie'] = game_roster.get(this_play.get('details').get('goalieInNetId'))     
                if this_play.get('details').get('eventOwnerTeamId') == pbp_data.get('homeTeam').get('id'): # Home team shooting
                    pbp_df.at[i,'Away_Goalie_Id'] = this_play.get('details').get('goalieInNetId')
                    pbp_df.at[i,'Away_Goalie'] = game_roster.get(this_play.get('details').get('goalieInNetId'))            
        
            if this_play.get('typeCode') == 505: # If it's a goal
                if type(this_play.get('details').get('shotType')) != NoneType: # If shotType is available
                    pbp_df.at[i,'Type'] = this_play.get('details').get('shotType').upper()
                pbp_df.at[i,'p1_ID'] = this_play.get('details').get('scoringPlayerId')
                pbp_df.at[i,'p1_name'] = game_roster.get(this_play.get('details').get('scoringPlayerId'))
                pbp_df.at[i,'p2_ID'] = this_play.get('details').get('assist1PlayerId')
                pbp_df.at[i,'p2_name'] = game_roster.get(this_play.get('details').get('assist1PlayerId'))
                pbp_df.at[i,'p3_ID'] = this_play.get('details').get('assist2PlayerId')
                pbp_df.at[i,'p3_name'] = game_roster.get(this_play.get('details').get('assist2PlayerId'))
                pbp_df.at[i,'Away_Score'] = this_play.get('details').get('awayScore')
                pbp_df.at[i,'Home_Score'] = this_play.get('details').get('homeScore')

            if this_play.get('typeCode') == 506: # If it's a shot on goal
                if type(this_play.get('details').get('shotType')) != NoneType: # If shotType is not available
                    pbp_df.at[i,'Type'] = this_play.get('details').get('shotType').upper()
                pbp_df.at[i,'p1_ID'] = this_play.get('details').get('shootingPlayerId')
                pbp_df.at[i,'p1_name'] = game_roster.get(this_play.get('details').get('shootingPlayerId'))

            if this_play.get('typeCode') == 507: # If it's a missed shot
                if type(this_play.get('details').get('shotType')) != NoneType: # If shotType is not available
                    pbp_df.at[i,'Type'] = this_play.get('details').get('shotType').upper()
                pbp_df.at[i,'p1_ID'] = this_play.get('details').get('shootingPlayerId')
                pbp_df.at[i,'p1_name'] = game_roster.get(this_play.get('details').get('shootingPlayerId'))

            if this_play.get('typeCode') == 508: # If it's blocked shot
                pbp_df.at[i,'p1_ID'] = this_play.get('details').get('blockingPlayerId')
                pbp_df.at[i,'p1_name'] = game_roster.get(this_play.get('details').get('blockingPlayerId'))
                pbp_df.at[i,'p2_ID'] = this_play.get('details').get('shootingPlayerId')
                pbp_df.at[i,'p2_name'] = game_roster.get(this_play.get('details').get('shootingPlayerId'))  
        
            if this_play.get('typeCode') == 509: # If it's a penalty
                pbp_df.at[i,'Type'] = this_play.get('details').get('typeCode') + ' for ' + this_play.get('details').get('descKey').upper()
                pbp_df.at[i,'p1_ID'] = this_play.get('details').get('committedByPlayerId')
                pbp_df.at[i,'p1_name'] = game_roster.get(this_play.get('details').get('committedByPlayerId'))
                pbp_df.at[i,'p2_ID'] = this_play.get('details').get('drawnByPlayerId')
                pbp_df.at[i,'p2_name'] = game_roster.get(this_play.get('details').get('drawnByPlayerId'))

            if this_play.get('typeCode') == 516: # If it's a stoppage
                pbp_df.at[i,'Type'] = this_play.get('details').get('reason').upper()

            if this_play.get('typeCode') == 525: # If it's a takeaway
                pbp_df.at[i,'p1_ID'] = this_play.get('details').get('playerId')
                pbp_df.at[i,'p1_name'] = game_roster.get(this_play.get('details').get('playerId'))

    #      if this_play.get('typeCode') == 535: # If it's a delayed penalty


            if this_play.get('typeCode') == 537: # If it's a failed shot attempt
                if type(this_play.get('details').get('shotType')) != NoneType: # If shotType is not available
                    pbp_df.at[i,'Type'] = this_play.get('details').get('shotType').upper()
                pbp_df.at[i,'p1_ID'] = this_play.get('details').get('shootingPlayerId')
                pbp_df.at[i,'p1_name'] = game_roster.get(this_play.get('details').get('shootingPlayerId'))

        # Adding Shift Data
        shifts = requests.get('https://api.nhle.com/stats/rest/en/shiftcharts?cayenneExp=gameId={}'.format(game_id))

        shift_data = shifts.json()
        shift_data.get('data')

        homePlayerList = ['homePlayer1_id','homePlayer2_id','homePlayer3_id','homePlayer4_id','homePlayer5_id','homePlayer6_id']
        homePlayerList_names = ['homePlayer1','homePlayer2','homePlayer3','homePlayer4','homePlayer5','homePlayer6']
        awayPlayerList = ['awayPlayer1_id','awayPlayer2_id','awayPlayer3_id','awayPlayer4_id','awayPlayer5_id','awayPlayer6_id']
        awayPlayerList_names = ['awayPlayer1','awayPlayer2','awayPlayer3','awayPlayer4','awayPlayer5','awayPlayer6']

        for i in range(len(shift_data.get('data'))):

            shift = shift_data.get('data')[i]

            period = shift.get('period')
            shift_start = datetime.strptime(shift.get('startTime'),'%M:%S')
            shift_end = datetime.strptime(shift.get('endTime'),'%M:%S')

            for j in range(len(pbp_df)):

                time_elapsed = datetime.strptime(pbp_df.at[j,'Time_Elapsed'],'%M:%S')

                awayPlayerList_loop = [pbp_df.at[j,'awayPlayer1_id'],pbp_df.at[j,'awayPlayer2_id'],pbp_df.at[j,'awayPlayer3_id'],
                                       pbp_df.at[j,'awayPlayer4_id'],pbp_df.at[j,'awayPlayer5_id'],pbp_df.at[j,'awayPlayer6_id']]
                homePlayerList_loop = [pbp_df.at[j,'homePlayer1_id'],pbp_df.at[j,'homePlayer2_id'],pbp_df.at[j,'homePlayer3_id'],
                                       pbp_df.at[j,'homePlayer4_id'],pbp_df.at[j,'homePlayer5_id'],pbp_df.at[j,'homePlayer6_id']]

                if (period == pbp_df.at[j,'Period']) & (shift_start <= time_elapsed < shift_end):

                    if shift.get('teamId') == awayTeam_Id:
                        if shift.get('playerId') not in awayPlayerList_loop:
                            for k in range(len(awayPlayerList)):
                                if pd.isna(pbp_df.at[j,awayPlayerList[k]]) == True:
                                    pbp_df.at[j,awayPlayerList[k]] = shift.get('playerId')
                                    pbp_df.at[j,awayPlayerList_names[k]] = game_roster.get(shift.get('playerId'))
                                    break

                    if shift.get('teamId') == homeTeam_Id:
                        if shift.get('playerId') not in homePlayerList_loop:
                            for k in range(len(homePlayerList)):
                                if pd.isna(pbp_df.at[j,homePlayerList[k]]) == True:
                                    pbp_df.at[j,homePlayerList[k]] = shift.get('playerId')
                                    pbp_df.at[j,homePlayerList_names[k]] = game_roster.get(shift.get('playerId'))
                                    break
                                
        return pbp_df

# %%
# %%time

# # Testing
# get_play_by_play(game_id)
# Out:
# Scraping Game Id 2023020172
# CPU times: total: 9.77 s
# Wall time: 18.4 s
#         Game_Id        Date Period Event_tc         Event Time_Elapsed  \
# 0    2023020172  2023-11-04      1      520  PERIOD_START        00:00
# 1    2023020172  2023-11-04      1      502       FACEOFF        00:00
# 2    2023020172  2023-11-04      1      503           HIT        00:41
# 3    2023020172  2023-11-04      1      525      TAKEAWAY        00:46
# 4    2023020172  2023-11-04      1      506  SHOT_ON_GOAL        00:51
# ..          ...         ...    ...      ...           ...          ...
# 285  2023020172  2023-11-04      3      516      STOPPAGE        19:46
# 286  2023020172  2023-11-04      3      502       FACEOFF        19:46
# 287  2023020172  2023-11-04      3      508  BLOCKED_SHOT        19:51
# 288  2023020172  2023-11-04      3      521    PERIOD_END        20:00
# 289  2023020172  2023-11-04      3      524      GAME_END        20:00
#
#     Strength Ev_Zone                      Type Ev_Team  ...       homePlayer6  \
# 0       1551     NaN                       NaN     NaN  ...   ANDREI KUZMENKO
# 1       1551       N                       NaN     DAL  ...   ANDREI KUZMENKO
# 2       1551       O                       NaN     VAN  ...      QUINN HUGHES
# 3       1551       D                       NaN     VAN  ...      QUINN HUGHES
# 4       1551       O                      SNAP     VAN  ...      QUINN HUGHES
# ..       ...     ...                       ...     ...  ...               ...
# 285     0651     NaN  GOALIE-STOPPED-AFTER-SOG     NaN  ...  ELIAS PETTERSSON
# 286     0651       D                       NaN     VAN  ...  ELIAS PETTERSSON
# 287     0651       D                       NaN     VAN  ...  ELIAS PETTERSSON
# 288     0651     NaN                       NaN     NaN  ...               NaN
# 289     0651     NaN                       NaN     NaN  ...               NaN
#
#     homePlayer6_id Away_Score Home_Score     Away_Goalie Away_Goalie_Id  \
# 0          8483808          0          0             NaN            NaN
# 1          8483808          0          0             NaN            NaN
# 2          8480800          0          0             NaN            NaN
# 3          8480800          0          0             NaN            NaN
# 4          8480800          0          0  JAKE OETTINGER        8479979
# ..             ...        ...        ...             ...            ...
# 285        8480012          0          2             NaN            NaN
# 286        8480012          0          2             NaN            NaN
# 287        8480012          0          2            None           None
# 288            NaN          0          2             NaN            NaN
# 289            NaN          0          2             NaN            NaN
#
#     Home_Goalie Home_Goalie_Id   xC   yC
# 0           NaN            NaN  NaN  NaN
# 1           NaN            NaN    0    0
# 2           NaN            NaN  -95  -27
# 3           NaN            NaN   50    6
# 4           NaN            NaN  -57   -4
# ..          ...            ...  ...  ...
# 285         NaN            NaN  NaN  NaN
# 286         NaN            NaN   69   22
# 287         NaN            NaN   42  -35
# 288         NaN            NaN  NaN  NaN
# 289         NaN            NaN  NaN  NaN
#
# [290 rows x 50 columns]

# %% [markdown]
# <br>
#
# ## Getting Play-By-Play for Multiple Games

# %%
def get_multi_play_by_play(range_of_ids):
    
    df = get_play_by_play(range_of_ids[0])
    
    for i in range(1,len(range_of_ids)):
        df2 = get_play_by_play(range_of_ids[i])
        df = pd.concat([df,df2],axis=0)
        
    return df

# %%
# Testing
# get_multi_play_by_play(game_ids)

# %% [markdown]
# <br>
