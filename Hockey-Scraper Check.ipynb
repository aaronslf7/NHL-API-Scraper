# %%
import pandas
import hockey_scraper as hs

# %%
pbp = hs.scrape_games([2023020001],False,data_format='Pandas')
# Out:
# Scraping the schedule between 2023-09-01 and 2024-4-27...please give it a moment
# Scraping Schedule: 100%|██████████| 35/35 [01:08<00:00,  1.96s/it]
# Scraping Game  2023020001 2023-10-10

# %%
pbp_df = pbp.get('pbp')
pbp_df
# Out:
#     Game_Id        Date  Period Event  \
# 0     20001  2023-10-10       1  PSTR
# 1     20001  2023-10-10       1   FAC
# 2     20001  2023-10-10       1  STOP
# 3     20001  2023-10-10       1   FAC
# 4     20001  2023-10-10       1   HIT
# ..      ...         ...     ...   ...
# 323   20001  2023-10-10       3  SHOT
# 324   20001  2023-10-10       3  GOAL
# 325   20001  2023-10-10       3   FAC
# 326   20001  2023-10-10       3  PEND
# 327   20001  2023-10-10       3  GEND
#
#                                            Description Time_Elapsed  \
# 0                   Period Start- Local time: 5:32 EDT         0:00
# 1    NSH won Neu. Zone - NSH #90 O'REILLY vs TBL #7...         0:00
# 2                                                ICING         0:35
# 3    TBL won Def. Zone - NSH #10 SISSONS vs TBL #71...         0:35
# 4        NSH #2 SCHENN HIT TBL #86 KUCHEROV, Def. Zone         0:48
# ..                                                 ...          ...
# ...

# %%
pbp_df.loc[pbp_df.Event == 'SHOT']
# Out:
#     Game_Id        Date  Period Event  \
# 6     20001  2023-10-10       1  SHOT
# 7     20001  2023-10-10       1  SHOT
# 9     20001  2023-10-10       1  SHOT
# 16    20001  2023-10-10       1  SHOT
# 28    20001  2023-10-10       1  SHOT
# 33    20001  2023-10-10       1  SHOT
# 40    20001  2023-10-10       1  SHOT
# 47    20001  2023-10-10       1  SHOT
# 49    20001  2023-10-10       1  SHOT
# 53    20001  2023-10-10       1  SHOT
# 57    20001  2023-10-10       1  SHOT
# 61    20001  2023-10-10       1  SHOT
# 74    20001  2023-10-10       1  SHOT
# 103   20001  2023-10-10       2  SHOT
# 109   20001  2023-10-10       2  SHOT
# 114   20001  2023-10-10       2  SHOT
# 116   20001  2023-10-10       2  SHOT
# 118   20001  2023-10-10       2  SHOT
# 119   20001  2023-10-10       2  SHOT
# 122   20001  2023-10-10       2  SHOT
# 124   20001  2023-10-10       2  SHOT
# 149   20001  2023-10-10       2  SHOT
# 155   20001  2023-10-10       2  SHOT
# ...
